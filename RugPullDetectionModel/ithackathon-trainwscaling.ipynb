# %%
path = '/kaggle/input/ithack/Jan_2024-Nov_2024.csv'

# %%
import pandas as pd
df = pd.read_csv(path)

# %%
df
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                              LIQUIDITY_POOL_ADDRESS  \
# 0      HLx5KbazmBafQfmjiYHWQaYqrXbDbJCAYLQci74sFVtR
# 1      4pJqcD8QmhLajJYn9muEtXJSz67H8FaKtzNknFubardo
# 2      5e6BdkPuafUJuWGiUm5zayGRTYNDy7WkDZzNfiFpuQts
# 3      65j8XPXjd5ZhoHPtWDY4kKZKbgjJQhALPisrWrgWDhBg
# 4      65j8XPXjd5ZhoHPtWDY4kKZKbgjJQhALPisrWrgWDhBg
# ...                                             ...
# 95428  GpqMSH1YM6oPmJ5xxEE2KfePf7uf5rXFbTW2TnxicRj6
# 95429  GpqMSH1YM6oPmJ5xxEE2KfePf7uf5rXFbTW2TnxicRj6
# 95430  AVs9TA4nWDzfPJE9gGVNJMVhcQy3V9PGazuz33BfG2RA
# 95431  AVs9TA4nWDzfPJE9gGVNJMVhcQy3V9PGazuz33BfG2RA
# 95432                                             ﻿
#
#                                                MINT  TOTAL_ADDED_LIQUIDITY  \
# 0      8KDsEUE3NdafcCVPqKrMrPfqh3oT4FzcxsYjwbMqpump           3.727000e+05
# 1      47uYAPNpAMJrLLxQZ7QQ9F1T6XBHqfPHLTfLsCCapump           3.584071e+06
# 2       uBR78nzmdk1W6wRxETznhW9jEuunn7ZTc9W3MGqpump           1.944022e+06
# 3      5p2zjqCd1WJzAVgcEnjhb9zWDU7b9XVhFhx4usiyN7jB           2.617475e+04
# 4      BxXmDhM8sTF3QG4foaVM2v1EUvg9DLSVUsDRTjR8tMyS           2.011766e+06
# ...                                             ...                    ...
# 95428  7dHbWXmci3dT8UFYWYZweBLXgycu7Y3iL6trKn1Y7ARj           4.163527e+01
# 95429   USDH1SM1ojwWUga67PGrgFWUHibbjqMvuMaDkRJTgkX           5.010918e+03
# 95430  4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R           2.231211e+06
# 95431   So11111111111111111111111111111111111111112           2.644296e+04
# 95432                                           NaN                    NaN
#
#        TOTAL_REMOVED_LIQUIDITY  NUM_LIQUIDITY_ADDS  NUM_LIQUIDITY_REMOVES  \
# 0                 6.930945e+04                 2.0                    1.0
# 1                 1.895394e+06                 1.0                    1.0
# 2                 2.960122e+06                17.0                   12.0
# 3                 3.546890e+04                 3.0                    1.0
# 4                 5.417064e+03                 3.0                    1.0
# ...                        ...                 ...                    ...
# 95428             1.059945e+02            392380.0                  188.0
# 95429             1.060718e+04            392380.0                  188.0
# 95430             6.508533e+06             15009.0                10346.0
# 95431             7.588321e+04             15009.0                10346.0
# 95432                      NaN                 NaN                    NaN
#
#        ADD_TO_REMOVE_RATIO LAST_POOL_ACTIVITY_TIMESTAMP  \
# 0                 5.377333      2024-10-31 23:52:02.000
# 1                 1.890937      2024-10-31 23:32:37.000
# 2                 0.656737      2024-10-31 23:52:37.000
# 3                 0.737963      2024-10-31 23:16:28.000
# 4               371.375729      2024-10-31 23:16:28.000
# ...                    ...                          ...
# 95428             0.392806      2024-08-05 19:34:18.000
# 95429             0.472408      2024-08-05 19:34:18.000
# 95430             0.342813      2024-10-31 18:33:28.000
# 95431             0.348469      2024-10-31 18:33:28.000
# 95432                  NaN                          NaN
#
#       FIRST_POOL_ACTIVITY_TIMESTAMP      LAST_SWAP_TIMESTAMP  \
# 0           2024-10-31 23:41:11.000  2024-10-31 23:59:38.000
# 1           2024-10-31 23:32:14.000  2024-10-31 23:59:52.000
# 2           2024-10-31 23:32:04.000  2024-10-31 23:59:56.000
# 3           2024-10-31 23:09:45.000  2024-10-31 23:57:39.000
# 4           2024-10-31 23:09:45.000  2024-10-31 23:56:38.000
# ...                             ...                      ...
# 95428       2024-01-01 00:00:07.000  2024-10-31 23:57:21.000
# 95429       2024-01-01 00:00:07.000  2024-10-31 23:50:20.000
# 95430       2024-01-01 00:00:02.000  2024-10-31 23:59:13.000
# 95431       2024-01-01 00:00:02.000  2024-11-01 00:00:00.000
# 95432                           NaN                      NaN
#
#                                          LAST_SWAP_TX_ID INACTIVITY_STATUS
# 0      3Uc1L6z3iR6x11WjSKR6QwQvDT87JV9tFXfYa7WPX8tek6...            Active
# 1      5keT61KU7SeBLgz4FJTY9QESTHyDvHGVJDmha1wKsMk5U5...            Active
# 2      34B7xqS6mcFyd71icighCHRTg2BW2NLPUUBxnfh71fbiWC...            Active
# 3      eADFKxhPWAaGNkA5St5i695315fCYkunBv1QeEJUL1kAfu...            Active
# 4      4L5DBSsSqjThXDodGiFGZd6RQUg9yQG79MSzbCSrcGkXMd...            Active
# ...                                                  ...               ...
# 95428  5LC8g3BCFvWEYFEmvmhoF3uvEyzJnKMpi76kLBYNXwoTot...            Active
# 95429  dfSuFu4VzyB499egHxcgN7RXALwgnLvYERnozdEedjsKoJ...            Active
# 95430  3SxFS8BVTXTQ62sX4g3PXZbVrUvj7zc9CvPbvDCCN7ZuSG...            Active
# 95431  58dWq6mucodktckyMxtjtyHaiPW7PdiKVgSCELMD3oQG4x...            Active
# 95432                                                NaN               NaN
#
# [95433 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['LIQUIDITY_POOL_ADDRESS', 'MINT', 'TOTAL_ADDED_LIQUIDITY',
#        'TOTAL_REMOVED_LIQUIDITY', 'NUM_LIQUIDITY_ADDS',
#        'NUM_LIQUIDITY_REMOVES', 'ADD_TO_REMOVE_RATIO',
#        'LAST_POOL_ACTIVITY_TIMESTAMP', 'FIRST_POOL_ACTIVITY_TIMESTAMP',
#        'LAST_SWAP_TIMESTAMP', 'LAST_SWAP_TX_ID', 'INACTIVITY_STATUS'],
#       dtype='object')

# %%
df.isna().sum() / len(df) * 100
# Out:
# LIQUIDITY_POOL_ADDRESS           0.000000
# MINT                             0.001048
# TOTAL_ADDED_LIQUIDITY            0.001048
# TOTAL_REMOVED_LIQUIDITY          0.001048
# NUM_LIQUIDITY_ADDS               0.001048
# NUM_LIQUIDITY_REMOVES            0.001048
# ADD_TO_REMOVE_RATIO              0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP     0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP    0.001048
# LAST_SWAP_TIMESTAMP              0.540693
# LAST_SWAP_TX_ID                  0.540693
# INACTIVITY_STATUS                0.001048
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.shape
# Out:
# (95433, 12)

# %%
df.head().to_dict()
# Out:
# {'LIQUIDITY_POOL_ADDRESS': {0: 'HLx5KbazmBafQfmjiYHWQaYqrXbDbJCAYLQci74sFVtR',
#   1: '4pJqcD8QmhLajJYn9muEtXJSz67H8FaKtzNknFubardo',
#   2: '5e6BdkPuafUJuWGiUm5zayGRTYNDy7WkDZzNfiFpuQts',
#   3: '65j8XPXjd5ZhoHPtWDY4kKZKbgjJQhALPisrWrgWDhBg',
#   4: '65j8XPXjd5ZhoHPtWDY4kKZKbgjJQhALPisrWrgWDhBg'},
#  'MINT': {0: '8KDsEUE3NdafcCVPqKrMrPfqh3oT4FzcxsYjwbMqpump',
#   1: '47uYAPNpAMJrLLxQZ7QQ9F1T6XBHqfPHLTfLsCCapump',
#   2: 'uBR78nzmdk1W6wRxETznhW9jEuunn7ZTc9W3MGqpump',
#   3: '5p2zjqCd1WJzAVgcEnjhb9zWDU7b9XVhFhx4usiyN7jB',
#   4: 'BxXmDhM8sTF3QG4foaVM2v1EUvg9DLSVUsDRTjR8tMyS'},
#  'TOTAL_ADDED_LIQUIDITY': {0: 372699.999937,
#   1: 3584071.0,
#   2: 1944021.819549,
#   3: 26174.75462778,
#   4: 2011766.101511},
#  'TOTAL_REMOVED_LIQUIDITY': {0: 69309.446048,
#   1: 1895394.482757,
#   2: 2960122.351972,
#   3: 35468.90254633,
#   4: 5417.064025},
#  'NUM_LIQUIDITY_ADDS': {0: 2.0, 1: 1.0, 2: 17.0, 3: 3.0, 4: 3.0},
#  'NUM_LIQUIDITY_REMOVES': {0: 1.0, 1: 1.0, 2: 12.0, 3: 1.0, 4: 1.0},
#  'ADD_TO_REMOVE_RATIO': {0: 5.377333411,
#   1: 1.890936706,
#   2: 0.6567369819,
#   3: 0.7379634764,
#   4: 371.375729035},
#  'LAST_POOL_ACTIVITY_TIMESTAMP': {0: '2024-10-31 23:52:02.000',
#   1: '2024-10-31 23:32:37.000',
#   2: '2024-10-31 23:52:37.000',
#   3: '2024-10-31 23:16:28.000',
#   4: '2024-10-31 23:16:28.000'},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP': {0: '2024-10-31 23:41:11.000',
#   1: '2024-10-31 23:32:14.000',
#   2: '2024-10-31 23:32:04.000',
#   3: '2024-10-31 23:09:45.000',
#   4: '2024-10-31 23:09:45.000'},
#  'LAST_SWAP_TIMESTAMP': {0: '2024-10-31 23:59:38.000',
#   1: '2024-10-31 23:59:52.000',
#   2: '2024-10-31 23:59:56.000',
#   3: '2024-10-31 23:57:39.000',
#   4: '2024-10-31 23:56:38.000'},
#  'LAST_SWAP_TX_ID': {0: '3Uc1L6z3iR6x11WjSKR6QwQvDT87JV9tFXfYa7WPX8tek6oRoAaKS4fXZiFr8m4aS2ovrgmcAU2nc8fsBCYFsUo6',
#   1: '5keT61KU7SeBLgz4FJTY9QESTHyDvHGVJDmha1wKsMk5U5nzTsLfHZqCAFA47Q797RhXUanqdjWxyufi3pxtCkE1',
#   2: '34B7xqS6mcFyd71icighCHRTg2BW2NLPUUBxnfh71fbiWCWbMfRyrQ633QuVSk3BDYyZx3NPPzRmWyNneAvc5oNS',
#   3: 'eADFKxhPWAaGNkA5St5i695315fCYkunBv1QeEJUL1kAfuG2GF7EfVK8We6xm1PNCtRHexHoqfwEbqbkmjznkWK',
#   4: '4L5DBSsSqjThXDodGiFGZd6RQUg9yQG79MSzbCSrcGkXMdB6aR1yJLcqGPPf3b6qJpDKzbDLZZY1NsRMxYxSztbQ'},
#  'INACTIVITY_STATUS': {0: 'Active',
#   1: 'Active',
#   2: 'Active',
#   3: 'Active',
#   4: 'Active'}}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95433 entries, 0 to 95432
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   LIQUIDITY_POOL_ADDRESS         95433 non-null  object
#  1   MINT                           95432 non-null  object
#  2   TOTAL_ADDED_LIQUIDITY          95432 non-null  float64
#  3   TOTAL_REMOVED_LIQUIDITY        95432 non-null  float64
#  4   NUM_LIQUIDITY_ADDS             95432 non-null  float64
#  5   NUM_LIQUIDITY_REMOVES          95432 non-null  float64
#  6   ADD_TO_REMOVE_RATIO            95432 non-null  float64
#  7   LAST_POOL_ACTIVITY_TIMESTAMP   95432 non-null  object
#  8   FIRST_POOL_ACTIVITY_TIMESTAMP  95432 non-null  object
#  9   LAST_SWAP_TIMESTAMP            94917 non-null  object
#  10  LAST_SWAP_TX_ID                94917 non-null  object
#  11  INACTIVITY_STATUS              95432 non-null  object
# dtypes: float64(5), object(7)
# memory usage: 8.7+ MB

# %%
timestamp_cols = [
    'LAST_POOL_ACTIVITY_TIMESTAMP',
    'FIRST_POOL_ACTIVITY_TIMESTAMP',
    'LAST_SWAP_TIMESTAMP'
]

for col in timestamp_cols:
    df[col] = df[col].str.split('.').str[0]
    df[col] = pd.to_datetime(df[col], format='%Y-%m-%d %H:%M:%S', errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95433 entries, 0 to 95432
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   LIQUIDITY_POOL_ADDRESS         95433 non-null  object
#  1   MINT                           95432 non-null  object
#  2   TOTAL_ADDED_LIQUIDITY          95432 non-null  float64
#  3   TOTAL_REMOVED_LIQUIDITY        95432 non-null  float64
#  4   NUM_LIQUIDITY_ADDS             95432 non-null  float64
#  5   NUM_LIQUIDITY_REMOVES          95432 non-null  float64
#  6   ADD_TO_REMOVE_RATIO            95432 non-null  float64
#  7   LAST_POOL_ACTIVITY_TIMESTAMP   95432 non-null  datetime64[ns]
#  8   FIRST_POOL_ACTIVITY_TIMESTAMP  95432 non-null  datetime64[ns]
#  9   LAST_SWAP_TIMESTAMP            94917 non-null  datetime64[ns]
#  10  LAST_SWAP_TX_ID                94917 non-null  object
#  11  INACTIVITY_STATUS              95432 non-null  object
# dtypes: datetime64[ns](3), float64(5), object(4)
# memory usage: 8.7+ MB

# %%
datetime_cols = df.select_dtypes(include=['datetime64[ns]']).columns.tolist()

for col in datetime_cols:
    df[f"{col}_ts"] = df[col].astype('int64') // 10**9  # Giây

# %%
for col in datetime_cols:
    df[f'{col}_hour'] = df[col].dt.hour
    df[f'{col}_day'] = df[col].dt.day
    df[f'{col}_weekday'] = df[col].dt.weekday  # Monday = 0, Sunday = 6
    df[f'{col}_month'] = df[col].dt.month

# %%
df.isna().sum() / len(df) * 100
# Out:
# LIQUIDITY_POOL_ADDRESS                   0.000000
# MINT                                     0.001048
# TOTAL_ADDED_LIQUIDITY                    0.001048
# TOTAL_REMOVED_LIQUIDITY                  0.001048
# NUM_LIQUIDITY_ADDS                       0.001048
# NUM_LIQUIDITY_REMOVES                    0.001048
# ADD_TO_REMOVE_RATIO                      0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP             0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP            0.001048
# LAST_SWAP_TIMESTAMP                      0.540693
# LAST_SWAP_TX_ID                          0.540693
# INACTIVITY_STATUS                        0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_ts          0.000000
# FIRST_POOL_ACTIVITY_TIMESTAMP_ts         0.000000
# LAST_SWAP_TIMESTAMP_ts                   0.000000
# LAST_POOL_ACTIVITY_TIMESTAMP_hour        0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_day         0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_weekday     0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_month       0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_hour       0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_day        0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_weekday    0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_month      0.001048
# LAST_SWAP_TIMESTAMP_hour                 0.540693
# LAST_SWAP_TIMESTAMP_day                  0.540693
# LAST_SWAP_TIMESTAMP_weekday              0.540693
# LAST_SWAP_TIMESTAMP_month                0.540693
# dtype: float64

# %%
df.shape
# Out:
# (95433, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95433 entries, 0 to 95432
# Data columns (total 27 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   LIQUIDITY_POOL_ADDRESS                 95433 non-null  object
#  1   MINT                                   95432 non-null  object
#  2   TOTAL_ADDED_LIQUIDITY                  95432 non-null  float64
#  3   TOTAL_REMOVED_LIQUIDITY                95432 non-null  float64
#  4   NUM_LIQUIDITY_ADDS                     95432 non-null  float64
#  5   NUM_LIQUIDITY_REMOVES                  95432 non-null  float64
#  6   ADD_TO_REMOVE_RATIO                    95432 non-null  float64
#  7   LAST_POOL_ACTIVITY_TIMESTAMP           95432 non-null  datetime64[ns]
#  8   FIRST_POOL_ACTIVITY_TIMESTAMP          95432 non-null  datetime64[ns]
#  9   LAST_SWAP_TIMESTAMP                    94917 non-null  datetime64[ns]
#  10  LAST_SWAP_TX_ID                        94917 non-null  object
#  11  INACTIVITY_STATUS                      95432 non-null  object
#  12  LAST_POOL_ACTIVITY_TIMESTAMP_ts        95433 non-null  int64
#  13  FIRST_POOL_ACTIVITY_TIMESTAMP_ts       95433 non-null  int64
#  14  LAST_SWAP_TIMESTAMP_ts                 95433 non-null  int64
#  15  LAST_POOL_ACTIVITY_TIMESTAMP_hour      95432 non-null  float64
#  16  LAST_POOL_ACTIVITY_TIMESTAMP_day       95432 non-null  float64
#  17  LAST_POOL_ACTIVITY_TIMESTAMP_weekday   95432 non-null  float64
#  18  LAST_POOL_ACTIVITY_TIMESTAMP_month     95432 non-null  float64
#  19  FIRST_POOL_ACTIVITY_TIMESTAMP_hour     95432 non-null  float64
#  20  FIRST_POOL_ACTIVITY_TIMESTAMP_day      95432 non-null  float64
#  21  FIRST_POOL_ACTIVITY_TIMESTAMP_weekday  95432 non-null  float64
#  22  FIRST_POOL_ACTIVITY_TIMESTAMP_month    95432 non-null  float64
#  23  LAST_SWAP_TIMESTAMP_hour               94917 non-null  float64
#  24  LAST_SWAP_TIMESTAMP_day                94917 non-null  float64
#  25  LAST_SWAP_TIMESTAMP_weekday            94917 non-null  float64
#  26  LAST_SWAP_TIMESTAMP_month              94917 non-null  float64
# dtypes: datetime64[ns](3), float64(17), int64(3), object(4)
# memory usage: 19.7+ MB

# %%
df.drop(columns=datetime_cols, inplace=True)

# %%
numeric_cols = df.select_dtypes(include=['float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

# %%
numeric_cols
# Out:
# ['TOTAL_ADDED_LIQUIDITY',
#  'TOTAL_REMOVED_LIQUIDITY',
#  'NUM_LIQUIDITY_ADDS',
#  'NUM_LIQUIDITY_REMOVES',
#  'ADD_TO_REMOVE_RATIO',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_day',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_month',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_day',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_month',
#  'LAST_SWAP_TIMESTAMP_hour',
#  'LAST_SWAP_TIMESTAMP_day',
#  'LAST_SWAP_TIMESTAMP_weekday',
#  'LAST_SWAP_TIMESTAMP_month']

# %%
categorical_cols
# Out:
# ['LIQUIDITY_POOL_ADDRESS', 'MINT', 'LAST_SWAP_TX_ID', 'INACTIVITY_STATUS']

# %%
for col in df.columns:
    print(f"{col}: {df[col].dtype}")
# Out:
# LIQUIDITY_POOL_ADDRESS: object
# MINT: object
# TOTAL_ADDED_LIQUIDITY: float64
# TOTAL_REMOVED_LIQUIDITY: float64
# NUM_LIQUIDITY_ADDS: float64
# NUM_LIQUIDITY_REMOVES: float64
# ADD_TO_REMOVE_RATIO: float64
# LAST_SWAP_TX_ID: object
# INACTIVITY_STATUS: object
# LAST_POOL_ACTIVITY_TIMESTAMP_ts: int64
# FIRST_POOL_ACTIVITY_TIMESTAMP_ts: int64
# LAST_SWAP_TIMESTAMP_ts: int64
# LAST_POOL_ACTIVITY_TIMESTAMP_hour: float64
# LAST_POOL_ACTIVITY_TIMESTAMP_day: float64
# LAST_POOL_ACTIVITY_TIMESTAMP_weekday: float64
# LAST_POOL_ACTIVITY_TIMESTAMP_month: float64
# FIRST_POOL_ACTIVITY_TIMESTAMP_hour: float64
# FIRST_POOL_ACTIVITY_TIMESTAMP_day: float64
# FIRST_POOL_ACTIVITY_TIMESTAMP_weekday: float64
# FIRST_POOL_ACTIVITY_TIMESTAMP_month: float64
# LAST_SWAP_TIMESTAMP_hour: float64
# LAST_SWAP_TIMESTAMP_day: float64
# LAST_SWAP_TIMESTAMP_weekday: float64
# LAST_SWAP_TIMESTAMP_month: float64

# %%
datetime_cols = df.select_dtypes(include=['datetime64[ns]']).columns.tolist()

for col in datetime_cols:
    df[f"{col}_ts"] = df[col].astype('int64') // 10**9  # Giây

# %%
for col in datetime_cols:
    df[f'{col}_hour'] = df[col].dt.hour
    df[f'{col}_day'] = df[col].dt.day
    df[f'{col}_weekday'] = df[col].dt.weekday  # Monday = 0, Sunday = 6
    df[f'{col}_month'] = df[col].dt.month

# %%
df.shape
# Out:
# (95433, 24)

# %%
df.drop(columns=datetime_cols, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95433 entries, 0 to 95432
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   LIQUIDITY_POOL_ADDRESS                 95433 non-null  object
#  1   MINT                                   95432 non-null  object
#  2   TOTAL_ADDED_LIQUIDITY                  95432 non-null  float64
#  3   TOTAL_REMOVED_LIQUIDITY                95432 non-null  float64
#  4   NUM_LIQUIDITY_ADDS                     95432 non-null  float64
#  5   NUM_LIQUIDITY_REMOVES                  95432 non-null  float64
#  6   ADD_TO_REMOVE_RATIO                    95432 non-null  float64
#  7   LAST_SWAP_TX_ID                        94917 non-null  object
#  8   INACTIVITY_STATUS                      95432 non-null  object
#  9   LAST_POOL_ACTIVITY_TIMESTAMP_ts        95433 non-null  int64
#  10  FIRST_POOL_ACTIVITY_TIMESTAMP_ts       95433 non-null  int64
#  11  LAST_SWAP_TIMESTAMP_ts                 95433 non-null  int64
#  12  LAST_POOL_ACTIVITY_TIMESTAMP_hour      95432 non-null  float64
#  13  LAST_POOL_ACTIVITY_TIMESTAMP_day       95432 non-null  float64
#  14  LAST_POOL_ACTIVITY_TIMESTAMP_weekday   95432 non-null  float64
#  15  LAST_POOL_ACTIVITY_TIMESTAMP_month     95432 non-null  float64
#  16  FIRST_POOL_ACTIVITY_TIMESTAMP_hour     95432 non-null  float64
#  17  FIRST_POOL_ACTIVITY_TIMESTAMP_day      95432 non-null  float64
#  18  FIRST_POOL_ACTIVITY_TIMESTAMP_weekday  95432 non-null  float64
#  19  FIRST_POOL_ACTIVITY_TIMESTAMP_month    95432 non-null  float64
#  20  LAST_SWAP_TIMESTAMP_hour               94917 non-null  float64
#  21  LAST_SWAP_TIMESTAMP_day                94917 non-null  float64
#  22  LAST_SWAP_TIMESTAMP_weekday            94917 non-null  float64
#  23  LAST_SWAP_TIMESTAMP_month              94917 non-null  float64
# dtypes: float64(17), int64(3), object(4)
# memory usage: 17.5+ MB

# %%
numeric_cols = df.select_dtypes(include=['number']).columns.tolist()
numeric_cols
# Out:
# ['TOTAL_ADDED_LIQUIDITY',
#  'TOTAL_REMOVED_LIQUIDITY',
#  'NUM_LIQUIDITY_ADDS',
#  'NUM_LIQUIDITY_REMOVES',
#  'ADD_TO_REMOVE_RATIO',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_ts',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_ts',
#  'LAST_SWAP_TIMESTAMP_ts',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_day',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_month',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_day',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_month',
#  'LAST_SWAP_TIMESTAMP_hour',
#  'LAST_SWAP_TIMESTAMP_day',
#  'LAST_SWAP_TIMESTAMP_weekday',
#  'LAST_SWAP_TIMESTAMP_month']

# %%
time_cols = ['LAST_SWAP_TIMESTAMP_hour', 'LAST_SWAP_TIMESTAMP_day', 
             'LAST_SWAP_TIMESTAMP_weekday', 'LAST_SWAP_TIMESTAMP_month']

df[time_cols] = df[time_cols].fillna(-1)

# %%
df.isna().sum() / len(df) * 100
# Out:
# LIQUIDITY_POOL_ADDRESS                   0.000000
# MINT                                     0.001048
# TOTAL_ADDED_LIQUIDITY                    0.001048
# TOTAL_REMOVED_LIQUIDITY                  0.001048
# NUM_LIQUIDITY_ADDS                       0.001048
# NUM_LIQUIDITY_REMOVES                    0.001048
# ADD_TO_REMOVE_RATIO                      0.001048
# LAST_SWAP_TX_ID                          0.540693
# INACTIVITY_STATUS                        0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_ts          0.000000
# FIRST_POOL_ACTIVITY_TIMESTAMP_ts         0.000000
# LAST_SWAP_TIMESTAMP_ts                   0.000000
# LAST_POOL_ACTIVITY_TIMESTAMP_hour        0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_day         0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_weekday     0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_month       0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_hour       0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_day        0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_weekday    0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_month      0.001048
# LAST_SWAP_TIMESTAMP_hour                 0.000000
# LAST_SWAP_TIMESTAMP_day                  0.000000
# LAST_SWAP_TIMESTAMP_weekday              0.000000
# LAST_SWAP_TIMESTAMP_month                0.000000
# dtype: float64

# %%
df = df.drop(columns=['LAST_SWAP_TX_ID'])

# %%
numeric_with_nan = [
    col for col in df.select_dtypes(include=['number']).columns 
    if df[col].isnull().any()
]
numeric_with_nan
# Out:
# ['TOTAL_ADDED_LIQUIDITY',
#  'TOTAL_REMOVED_LIQUIDITY',
#  'NUM_LIQUIDITY_ADDS',
#  'NUM_LIQUIDITY_REMOVES',
#  'ADD_TO_REMOVE_RATIO',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_day',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_month',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_day',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_month']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in numeric_with_nan:
    plt.figure(figsize=(6, 1.5))
    sns.kdeplot(data=df, x=col, color="skyblue", fill=True, linewidth=2, bw_adjust=0.5)
    sns.rugplot(data=df, x=col, color="red", height=0.1)
    plt.title(f'KDE Plot with Outliers: {col}')
    plt.xlabel(col)
    plt.tight_layout()
    plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
col_to_fill_0 = ['TOTAL_ADDED_LIQUIDITY',                    
'TOTAL_REMOVED_LIQUIDITY',                  
'NUM_LIQUIDITY_ADDS',                       
'NUM_LIQUIDITY_REMOVES',                    
'ADD_TO_REMOVE_RATIO']
df[col_to_fill_0] = df[col_to_fill_0].fillna(0)

# %%
df.dropna(subset=['MINT'], inplace=True)

# %%
# Danh sách 8 cột đặc trưng thời gian suy ra
time_derived_features_to_fill = [
    'LAST_POOL_ACTIVITY_TIMESTAMP_hour',
    'LAST_POOL_ACTIVITY_TIMESTAMP_day',
    'LAST_POOL_ACTIVITY_TIMESTAMP_weekday',
    'LAST_POOL_ACTIVITY_TIMESTAMP_month',
    'FIRST_POOL_ACTIVITY_TIMESTAMP_hour',
    'FIRST_POOL_ACTIVITY_TIMESTAMP_day',
    'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday',
    'FIRST_POOL_ACTIVITY_TIMESTAMP_month'
]

for col in time_derived_features_to_fill:
    if col in df.columns:
        df[col].fillna(-1, inplace=True)

print("\nSố lượng NaN ở các cột thời gian suy ra sau khi điền:")
print(df[time_derived_features_to_fill].isnull().sum())
# Out:
# Số lượng NaN ở các cột thời gian suy ra sau khi điền:
# LAST_POOL_ACTIVITY_TIMESTAMP_hour        0
# LAST_POOL_ACTIVITY_TIMESTAMP_day         0
# LAST_POOL_ACTIVITY_TIMESTAMP_weekday     0
# LAST_POOL_ACTIVITY_TIMESTAMP_month       0
# FIRST_POOL_ACTIVITY_TIMESTAMP_hour       0
# FIRST_POOL_ACTIVITY_TIMESTAMP_day        0
# FIRST_POOL_ACTIVITY_TIMESTAMP_weekday    0
# FIRST_POOL_ACTIVITY_TIMESTAMP_month      0
# dtype: int64
# /tmp/ipykernel_128/860428239.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(-1, inplace=True)

# %%
df.isna().sum()/len(df)*100
# Out:
# LIQUIDITY_POOL_ADDRESS                   0.0
# MINT                                     0.0
# TOTAL_ADDED_LIQUIDITY                    0.0
# TOTAL_REMOVED_LIQUIDITY                  0.0
# NUM_LIQUIDITY_ADDS                       0.0
# NUM_LIQUIDITY_REMOVES                    0.0
# ADD_TO_REMOVE_RATIO                      0.0
# INACTIVITY_STATUS                        0.0
# LAST_POOL_ACTIVITY_TIMESTAMP_ts          0.0
# FIRST_POOL_ACTIVITY_TIMESTAMP_ts         0.0
# LAST_SWAP_TIMESTAMP_ts                   0.0
# LAST_POOL_ACTIVITY_TIMESTAMP_hour        0.0
# LAST_POOL_ACTIVITY_TIMESTAMP_day         0.0
# LAST_POOL_ACTIVITY_TIMESTAMP_weekday     0.0
# LAST_POOL_ACTIVITY_TIMESTAMP_month       0.0
# FIRST_POOL_ACTIVITY_TIMESTAMP_hour       0.0
# FIRST_POOL_ACTIVITY_TIMESTAMP_day        0.0
# FIRST_POOL_ACTIVITY_TIMESTAMP_weekday    0.0
# FIRST_POOL_ACTIVITY_TIMESTAMP_month      0.0
# LAST_SWAP_TIMESTAMP_hour                 0.0
# LAST_SWAP_TIMESTAMP_day                  0.0
# LAST_SWAP_TIMESTAMP_weekday              0.0
# LAST_SWAP_TIMESTAMP_month                0.0
# dtype: float64

# %%
inactivity_status_one_hot = pd.get_dummies(df['INACTIVITY_STATUS'], prefix='INACTIVITY_STATUS')


df = pd.concat([df, inactivity_status_one_hot], axis=1)

df.drop('INACTIVITY_STATUS', axis=1, inplace=True)

# %%
estimated_contamination = 0.005

# %%
import optuna
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import train_test_split 

def objective(trial, X_data):

    # Gợi ý các tham số cho Isolation Forest
    n_estimators = trial.suggest_int('n_estimators', 50, 300) # Số cây trong rừng
    max_samples = trial.suggest_int('max_samples', 100, min(2048, len(X_data))) # Số mẫu lấy để xây cây
    
    model = IsolationForest(n_estimators=n_estimators,
                            max_samples=max_samples,
                            contamination=estimated_contamination, # Sử dụng giá trị ước tính
                            random_state=trial.number) # Sử dụng trial.number để đa dạng hóa seed

    # Fit mô hình với toàn bộ tập dữ liệu đặc trưng
    model.fit(X_data)

    # Tính điểm bất thường
    anomaly_scores = model.decision_function(X_data)

    # Phân loại điểm thành "inliers" (điểm > 0) và "outliers" (điểm <= 0) dựa trên ngưỡng 0
    # (trước khi áp dụng ngưỡng contamination)
    inlier_scores = anomaly_scores[anomaly_scores > 0]
    outlier_scores = anomaly_scores[anomaly_scores <= 0]

    # Tính điểm trung vị cho từng nhóm
    # Xử lý trường hợp một trong hai nhóm rỗng
    median_inlier = np.median(inlier_scores) if len(inlier_scores) > 0 else 0
    median_outlier = np.median(outlier_scores) if len(outlier_scores) > 0 else 0

    # Hàm mục tiêu: Tối đa hóa sự khác biệt giữa trung vị inlier và trung vị outlier
    # Điểm bất thường càng âm càng tốt, nên median_outlier sẽ là một số âm.
    # median_inlier - median_outlier = median_inlier + abs(median_outlier) -> muốn giá trị này lớn
    objective_value = median_inlier - median_outlier

    # Optuna mặc định tìm cách minimize. Để tối đa hóa, ta trả về giá trị âm
    return -objective_value

# %%
columns_to_drop_for_X = [
    'LIQUIDITY_POOL_ADDRESS',
    'MINT', 
    'LAST_SWAP_TX_ID', 
    'LAST_POOL_ACTIVITY_TIMESTAMP_ts',
    'FIRST_POOL_ACTIVITY_TIMESTAMP_ts',
    'LAST_SWAP_TIMESTAMP_ts'
]
X = df.drop(columns=columns_to_drop_for_X, errors='ignore')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)
X_scaled_df.head()
# Out:
#    TOTAL_ADDED_LIQUIDITY  TOTAL_REMOVED_LIQUIDITY  NUM_LIQUIDITY_ADDS  \
# 0              -0.008871                -0.012606           -0.029401
# 1              -0.008871                -0.012606           -0.029477
# 2              -0.008871                -0.012606           -0.028265
# 3              -0.008871                -0.012606           -0.029326
# 4              -0.008871                -0.012606           -0.029326
#
#    NUM_LIQUIDITY_REMOVES  ADD_TO_REMOVE_RATIO  \
# 0              -0.024714            -0.008216
# 1              -0.024714            -0.008216
# 2              -0.023854            -0.008216
# 3              -0.024714            -0.008216
# 4              -0.024714            -0.008178
#
#    LAST_POOL_ACTIVITY_TIMESTAMP_hour  LAST_POOL_ACTIVITY_TIMESTAMP_day  \
# 0                           1.515921                          1.482466
# 1                           1.515921                          1.482466
# 2                           1.515921                          1.482466
# 3                           1.515921                          1.482466
# 4                           1.515921                          1.482466
#
#    LAST_POOL_ACTIVITY_TIMESTAMP_weekday  LAST_POOL_ACTIVITY_TIMESTAMP_month  \
# 0                              0.043632                            1.191685
# 1                              0.043632                            1.191685
# 2                              0.043632                            1.191685
# 3                              0.043632                            1.191685
# 4                              0.043632                            1.191685
#
#    FIRST_POOL_ACTIVITY_TIMESTAMP_hour  FIRST_POOL_ACTIVITY_TIMESTAMP_day  \
# 0                            1.557532                           1.714879
# 1                            1.557532                           1.714879
# 2                            1.557532                           1.714879
# 3                            1.557532                           1.714879
# 4                            1.557532                           1.714879
#
#    FIRST_POOL_ACTIVITY_TIMESTAMP_weekday  FIRST_POOL_ACTIVITY_TIMESTAMP_month  \
# 0                               0.064234                             1.576563
# 1                               0.064234                             1.576563
# 2                               0.064234                             1.576563
# 3                               0.064234                             1.576563
# 4                               0.064234                             1.576563
#
#    LAST_SWAP_TIMESTAMP_hour  LAST_SWAP_TIMESTAMP_day  \
# 0                  1.232931                 0.979497
# 1                  1.232931                 0.979497
# 2                  1.232931                 0.979497
# 3                  1.232931                 0.979497
# 4                  1.232931                 0.979497
#
#    LAST_SWAP_TIMESTAMP_weekday  LAST_SWAP_TIMESTAMP_month  \
# 0                     -0.20073                   0.014898
# 1                     -0.20073                   0.014898
# 2                     -0.20073                   0.014898
# 3                     -0.20073                   0.014898
# 4                     -0.20073                   0.014898
#
#    INACTIVITY_STATUS_Active  INACTIVITY_STATUS_Inactive
# 0                  0.499797                   -0.499797
# 1                  0.499797                   -0.499797
# 2                  0.499797                   -0.499797
# 3                  0.499797                   -0.499797
# 4                  0.499797                   -0.499797

# %%
study = optuna.create_study(direction='minimize')
study.optimize(lambda trial: objective(trial, X_scaled), n_trials=100) 
# In ra kết quả tốt nhất
print("\nKết quả tối ưu hóa:")
print(f"Tham số tốt nhất: {study.best_params}")
print(f"Giá trị hàm mục tiêu tốt nhất (âm của sự khác biệt trung vị): {study.best_value}")
# Out:
# [I 2025-05-22 01:20:49,702] A new study created in memory with name: no-name-4762717c-42ae-4607-be68-c234d884490e
# [I 2025-05-22 01:21:06,095] Trial 0 finished with value: -0.18562835898429872 and parameters: {'n_estimators': 247, 'max_samples': 1495}. Best is trial 0 with value: -0.18562835898429872.
# [I 2025-05-22 01:21:23,473] Trial 1 finished with value: -0.1888420543151365 and parameters: {'n_estimators': 297, 'max_samples': 437}. Best is trial 1 with value: -0.1888420543151365.
# [I 2025-05-22 01:21:39,939] Trial 2 finished with value: -0.19864775458504508 and parameters: {'n_estimators': 265, 'max_samples': 608}. Best is trial 2 with value: -0.19864775458504508.
# [I 2025-05-22 01:21:58,762] Trial 3 finished with value: -0.18633446978788087 and parameters: {'n_estimators': 286, 'max_samples': 1839}. Best is trial 2 with value: -0.19864775458504508.
# [I 2025-05-22 01:22:15,161] Trial 4 finished with value: -0.19369941998066192 and parameters: {'n_estimators': 246, 'max_samples': 1217}. Best is trial 2 with value: -0.19864775458504508.
# [I 2025-05-22 01:22:33,190] Trial 5 finished with value: -0.19934399196875882 and parameters: {'n_estimators': 287, 'max_samples': 591}. Best is trial 5 with value: -0.19934399196875882.
# [I 2025-05-22 01:22:43,481] Trial 6 finished with value: -0.19083765165220803 and parameters: {'n_estimators': 156, 'max_samples': 1448}. Best is trial 5 with value: -0.19934399196875882.
# [I 2025-05-22 01:23:02,884] Trial 7 finished with value: -0.18944179741526748 and parameters: {'n_estimators': 290, 'max_samples': 1077}. Best is trial 5 with value: -0.19934399196875882.
# [I 2025-05-22 01:23:14,803] Trial 8 finished with value: -0.18622472035056928 and parameters: {'n_estimators': 183, 'max_samples': 1878}. Best is trial 5 with value: -0.19934399196875882.
# [I 2025-05-22 01:23:25,585] Trial 9 finished with value: -0.1890188429649814 and parameters: {'n_estimators': 162, 'max_samples': 1059}. Best is trial 5 with value: -0.19934399196875882.
# [I 2025-05-22 01:23:29,656] Trial 10 finished with value: -0.197445153085547 and parameters: {'n_estimators': 73, 'max_samples': 157}. Best is trial 5 with value: -0.19934399196875882.
# [I 2025-05-22 01:23:43,826] Trial 11 finished with value: -0.19324741274656793 and parameters: {'n_estimators': 225, 'max_samples': 677}. Best is trial 5 with value: -0.19934399196875882.
# [I 2025-05-22 01:23:56,702] Trial 12 finished with value: -0.19069397439379673 and parameters: {'n_estimators': 206, 'max_samples': 677}. Best is trial 5 with value: -0.19934399196875882.
# [I 2025-05-22 01:24:04,153] Trial 13 finished with value: -0.20045624660580655 and parameters: {'n_estimators': 118, 'max_samples': 709}. Best is trial 13 with value: -0.20045624660580655.
# [I 2025-05-22 01:24:10,127] Trial 14 finished with value: -0.17937071408165003 and parameters: {'n_estimators': 109, 'max_samples': 212}. Best is trial 13 with value: -0.20045624660580655.
# [I 2025-05-22 01:24:17,734] Trial 15 finished with value: -0.19207057858258514 and parameters: {'n_estimators': 121, 'max_samples': 851}. Best is trial 13 with value: -0.20045624660580655.
# [I 2025-05-22 01:24:20,866] Trial 16 finished with value: -0.1912095218807951 and parameters: {'n_estimators': 54, 'max_samples': 450}. Best is trial 13 with value: -0.20045624660580655.
# [I 2025-05-22 01:24:28,594] Trial 17 finished with value: -0.18499583173465495 and parameters: {'n_estimators': 122, 'max_samples': 899}. Best is trial 13 with value: -0.20045624660580655.
# [I 2025-05-22 01:24:33,826] Trial 18 finished with value: -0.19241195716288204 and parameters: {'n_estimators': 89, 'max_samples': 420}. Best is trial 13 with value: -0.20045624660580655.
# [I 2025-05-22 01:24:42,992] Trial 19 finished with value: -0.19381463036396027 and parameters: {'n_estimators': 145, 'max_samples': 834}. Best is trial 13 with value: -0.20045624660580655.
# [I 2025-05-22 01:24:54,100] Trial 20 finished with value: -0.2085389723559144 and parameters: {'n_estimators': 189, 'max_samples': 266}. Best is trial 20 with value: -0.2085389723559144.
# [I 2025-05-22 01:25:06,062] Trial 21 finished with value: -0.1866527209228609 and parameters: {'n_estimators': 201, 'max_samples': 258}. Best is trial 20 with value: -0.2085389723559144.
# [I 2025-05-22 01:25:16,679] Trial 22 finished with value: -0.19039691009483084 and parameters: {'n_estimators': 181, 'max_samples': 511}. Best is trial 20 with value: -0.2085389723559144.
# [I 2025-05-22 01:25:24,926] Trial 23 finished with value: -0.19640181296851905 and parameters: {'n_estimators': 141, 'max_samples': 313}. Best is trial 20 with value: -0.2085389723559144.
# [I 2025-05-22 01:25:29,660] Trial 24 finished with value: -0.19602819901415242 and parameters: {'n_estimators': 92, 'max_samples': 112}. Best is trial 20 with value: -0.2085389723559144.
# [I 2025-05-22 01:25:42,724] Trial 25 finished with value: -0.20273425704197073 and parameters: {'n_estimators': 205, 'max_samples': 705}. Best is trial 20 with value: -0.2085389723559144.
# [I 2025-05-22 01:25:56,120] Trial 26 finished with value: -0.19242558708518637 and parameters: {'n_estimators': 209, 'max_samples': 782}. Best is trial 20 with value: -0.2085389723559144.
# [I 2025-05-22 01:26:10,285] Trial 27 finished with value: -0.1862841672876966 and parameters: {'n_estimators': 225, 'max_samples': 1010}. Best is trial 20 with value: -0.2085389723559144.
# [I 2025-05-22 01:26:21,640] Trial 28 finished with value: -0.19317865344887664 and parameters: {'n_estimators': 169, 'max_samples': 1291}. Best is trial 20 with value: -0.2085389723559144.
# [I 2025-05-22 01:26:33,683] Trial 29 finished with value: -0.19434657496934177 and parameters: {'n_estimators': 191, 'max_samples': 730}. Best is trial 20 with value: -0.2085389723559144.
# [I 2025-05-22 01:26:49,142] Trial 30 finished with value: -0.181607773790823 and parameters: {'n_estimators': 233, 'max_samples': 2032}. Best is trial 20 with value: -0.2085389723559144.
# [I 2025-05-22 01:27:05,830] Trial 31 finished with value: -0.19282091075455007 and parameters: {'n_estimators': 265, 'max_samples': 594}. Best is trial 20 with value: -0.2085389723559144.
# [I 2025-05-22 01:27:20,799] Trial 32 finished with value: -0.19597052826648842 and parameters: {'n_estimators': 256, 'max_samples': 350}. Best is trial 20 with value: -0.2085389723559144.
# [I 2025-05-22 01:27:28,752] Trial 33 finished with value: -0.2102074822960471 and parameters: {'n_estimators': 127, 'max_samples': 537}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:27:37,456] Trial 34 finished with value: -0.19652380075204906 and parameters: {'n_estimators': 138, 'max_samples': 528}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:27:44,741] Trial 35 finished with value: -0.19792064310546706 and parameters: {'n_estimators': 124, 'max_samples': 378}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:27:51,268] Trial 36 finished with value: -0.19336310314200614 and parameters: {'n_estimators': 102, 'max_samples': 951}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:28:00,312] Trial 37 finished with value: -0.19429494752296284 and parameters: {'n_estimators': 156, 'max_samples': 509}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:28:11,945] Trial 38 finished with value: -0.19551974899674832 and parameters: {'n_estimators': 173, 'max_samples': 1240}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:28:23,839] Trial 39 finished with value: -0.20336891993637987 and parameters: {'n_estimators': 189, 'max_samples': 634}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:28:35,153] Trial 40 finished with value: -0.1927093412136477 and parameters: {'n_estimators': 194, 'max_samples': 260}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:28:48,720] Trial 41 finished with value: -0.19227770193387397 and parameters: {'n_estimators': 216, 'max_samples': 662}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:29:00,340] Trial 42 finished with value: -0.19217220343172184 and parameters: {'n_estimators': 186, 'max_samples': 781}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:29:15,273] Trial 43 finished with value: -0.1985435531873049 and parameters: {'n_estimators': 238, 'max_samples': 572}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:29:26,445] Trial 44 finished with value: -0.18913378035557318 and parameters: {'n_estimators': 164, 'max_samples': 1111}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:29:36,515] Trial 45 finished with value: -0.18936823997663435 and parameters: {'n_estimators': 152, 'max_samples': 1650}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:29:44,075] Trial 46 finished with value: -0.1994684713142324 and parameters: {'n_estimators': 129, 'max_samples': 470}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:29:55,290] Trial 47 finished with value: -0.19670795612849526 and parameters: {'n_estimators': 178, 'max_samples': 716}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:29:59,920] Trial 48 finished with value: -0.2014235910540871 and parameters: {'n_estimators': 74, 'max_samples': 616}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:30:13,835] Trial 49 finished with value: -0.20359137501562524 and parameters: {'n_estimators': 218, 'max_samples': 599}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:30:26,437] Trial 50 finished with value: -0.1997473973874201 and parameters: {'n_estimators': 217, 'max_samples': 314}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:30:38,925] Trial 51 finished with value: -0.19385176329579312 and parameters: {'n_estimators': 198, 'max_samples': 619}. Best is trial 33 with value: -0.2102074822960471.
# [I 2025-05-22 01:30:42,003] Trial 52 finished with value: -0.2259861159218264 and parameters: {'n_estimators': 52, 'max_samples': 413}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:30:44,849] Trial 53 finished with value: -0.19449344410896324 and parameters: {'n_estimators': 51, 'max_samples': 207}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:30:57,175] Trial 54 finished with value: -0.18973360815870105 and parameters: {'n_estimators': 210, 'max_samples': 381}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:31:00,922] Trial 55 finished with value: -0.18631251437251942 and parameters: {'n_estimators': 63, 'max_samples': 448}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:31:16,762] Trial 56 finished with value: -0.1975881299385985 and parameters: {'n_estimators': 248, 'max_samples': 552}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:31:29,397] Trial 57 finished with value: -0.19373537001015495 and parameters: {'n_estimators': 229, 'max_samples': 173}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:31:41,228] Trial 58 finished with value: -0.1967403107140741 and parameters: {'n_estimators': 202, 'max_samples': 271}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:31:54,794] Trial 59 finished with value: -0.19514515109470063 and parameters: {'n_estimators': 213, 'max_samples': 836}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:32:05,899] Trial 60 finished with value: -0.19696379307080158 and parameters: {'n_estimators': 189, 'max_samples': 420}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:32:10,631] Trial 61 finished with value: -0.1894724807707547 and parameters: {'n_estimators': 74, 'max_samples': 763}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:32:15,725] Trial 62 finished with value: -0.2033827324062687 and parameters: {'n_estimators': 81, 'max_samples': 655}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:32:19,648] Trial 63 finished with value: -0.20190373300076264 and parameters: {'n_estimators': 62, 'max_samples': 648}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:32:25,251] Trial 64 finished with value: -0.19070632385546457 and parameters: {'n_estimators': 87, 'max_samples': 924}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:32:30,214] Trial 65 finished with value: -0.19871032350839327 and parameters: {'n_estimators': 83, 'max_samples': 503}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:32:37,072] Trial 66 finished with value: -0.20283408872746325 and parameters: {'n_estimators': 108, 'max_samples': 692}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:32:42,987] Trial 67 finished with value: -0.19427066092216122 and parameters: {'n_estimators': 102, 'max_samples': 405}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:32:49,963] Trial 68 finished with value: -0.19785221159176108 and parameters: {'n_estimators': 112, 'max_samples': 562}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:32:55,597] Trial 69 finished with value: -0.19945095716532962 and parameters: {'n_estimators': 99, 'max_samples': 348}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:32:59,759] Trial 70 finished with value: -0.19276946889191685 and parameters: {'n_estimators': 65, 'max_samples': 862}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:33:08,129] Trial 71 finished with value: -0.19914867926208063 and parameters: {'n_estimators': 132, 'max_samples': 688}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:33:13,816] Trial 72 finished with value: -0.1947553316425782 and parameters: {'n_estimators': 111, 'max_samples': 100}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:33:18,842] Trial 73 finished with value: -0.1977037900364357 and parameters: {'n_estimators': 79, 'max_samples': 753}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:33:24,485] Trial 74 finished with value: -0.20097001955821292 and parameters: {'n_estimators': 97, 'max_samples': 471}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:33:38,592] Trial 75 finished with value: -0.19777542870901574 and parameters: {'n_estimators': 222, 'max_samples': 626}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:33:42,459] Trial 76 finished with value: -0.1929841603707361 and parameters: {'n_estimators': 59, 'max_samples': 691}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:33:53,331] Trial 77 finished with value: -0.19294691951260076 and parameters: {'n_estimators': 170, 'max_samples': 531}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:34:05,796] Trial 78 finished with value: -0.1883875380396279 and parameters: {'n_estimators': 182, 'max_samples': 1112}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:34:18,697] Trial 79 finished with value: -0.18409336277468127 and parameters: {'n_estimators': 204, 'max_samples': 985}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:34:28,188] Trial 80 finished with value: -0.19641115390608796 and parameters: {'n_estimators': 149, 'max_samples': 805}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:34:32,497] Trial 81 finished with value: -0.2006702214824116 and parameters: {'n_estimators': 67, 'max_samples': 651}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:34:36,934] Trial 82 finished with value: -0.19749167314512003 and parameters: {'n_estimators': 69, 'max_samples': 574}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:34:40,534] Trial 83 finished with value: -0.19791331546341606 and parameters: {'n_estimators': 56, 'max_samples': 733}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:34:43,836] Trial 84 finished with value: -0.20102544818740897 and parameters: {'n_estimators': 51, 'max_samples': 651}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:34:48,637] Trial 85 finished with value: -0.20147199236561153 and parameters: {'n_estimators': 81, 'max_samples': 491}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:34:59,967] Trial 86 finished with value: -0.20115657325075226 and parameters: {'n_estimators': 194, 'max_samples': 307}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:35:07,447] Trial 87 finished with value: -0.19572202153731488 and parameters: {'n_estimators': 117, 'max_samples': 879}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:35:17,748] Trial 88 finished with value: -0.18720015286337713 and parameters: {'n_estimators': 163, 'max_samples': 596}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:35:21,956] Trial 89 finished with value: -0.1892900539359903 and parameters: {'n_estimators': 62, 'max_samples': 1558}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:35:27,874] Trial 90 finished with value: -0.19539686172951728 and parameters: {'n_estimators': 92, 'max_samples': 798}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:35:32,882] Trial 91 finished with value: -0.1824894413627999 and parameters: {'n_estimators': 85, 'max_samples': 500}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:35:37,610] Trial 92 finished with value: -0.18854018756020993 and parameters: {'n_estimators': 79, 'max_samples': 464}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:35:44,408] Trial 93 finished with value: -0.1936632614059799 and parameters: {'n_estimators': 106, 'max_samples': 698}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:35:49,070] Trial 94 finished with value: -0.18474923545535854 and parameters: {'n_estimators': 79, 'max_samples': 384}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:35:54,141] Trial 95 finished with value: -0.19520918490630906 and parameters: {'n_estimators': 93, 'max_samples': 201}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:36:06,602] Trial 96 finished with value: -0.203876748489666 and parameters: {'n_estimators': 198, 'max_samples': 536}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:36:17,807] Trial 97 finished with value: -0.19255025982239765 and parameters: {'n_estimators': 175, 'max_samples': 538}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:36:30,300] Trial 98 finished with value: -0.19760499517539734 and parameters: {'n_estimators': 198, 'max_samples': 634}. Best is trial 52 with value: -0.2259861159218264.
# [I 2025-05-22 01:36:41,164] Trial 99 finished with value: -0.2007689266472087 and parameters: {'n_estimators': 186, 'max_samples': 433}. Best is trial 52 with value: -0.2259861159218264.
# Kết quả tối ưu hóa:
# Tham số tốt nhất: {'n_estimators': 52, 'max_samples': 413}
# Giá trị hàm mục tiêu tốt nhất (âm của sự khác biệt trung vị): -0.2259861159218264

# %%
best_params = study.best_params
best_model = IsolationForest(n_estimators=best_params['n_estimators'],
                             max_samples=best_params['max_samples'],
                             contamination=estimated_contamination, 
                             random_state=42) 

# Fit mô hình tốt nhất với toàn bộ dữ liệu để sử dụng
best_model.fit(X_scaled)
# Out:
# IsolationForest(contamination=0.005, max_samples=413, n_estimators=52,
#                 random_state=42)

# %%
# Bây giờ bạn có thể sử dụng best_model để tính điểm bất thường và dự đoán nhãn
anomaly_scores_tuned = best_model.decision_function(X_scaled)
predictions_tuned = best_model.predict(X_scaled)

# %%
df['anomaly_score_isolation_forest'] = anomaly_scores_tuned
df['is_outlier_isolation_forest'] = predictions_tuned

# %%
# Xem 10 hàng có điểm bất thường thấp nhất (bất thường nhất)
top_anomalies = df.sort_values(by='anomaly_score_isolation_forest').head(10)
print("\nTop 10 ứng viên Rug Pull dựa trên điểm bất thường:")
print(top_anomalies)

# Xem tất cả các hàng được dự đoán là outliers (-1)
predicted_outliers_df = df[df['is_outlier_isolation_forest'] == -1]
print(f"\nSố lượng điểm được dự đoán là outliers: {len(predicted_outliers_df)}")
print("Thông tin về các điểm được dự đoán là outliers:")
print(predicted_outliers_df.head())
# Out:
# Top 10 ứng viên Rug Pull dựa trên điểm bất thường:
#                              LIQUIDITY_POOL_ADDRESS  \
# 95256  3ne4mWqdYuNiYrYZC9TrA3FcfuFdErghH97vNPbjicr1
# 95408  8QaXeHBrShJTdtN1rWCccBxpSVvKksQ2PCu5nufb2zbk
# 47606  Fptmpk3UW6KcVTFFpoWv53eiji8dn2jVaZDNhHEhxCYy
# 29575  7sJ6qfKZvSNqSSPJKTVZBww21SQuAr5CDy8TUzNPjG6b
# 82222  4sq2VviSRTNDg1Fdm1VzbbeCWgkqFJtWWAqHhfAYFrXs
# 11961  5no8Tr7WBcXjTEwtLa6MVuzFvL6Liv1rnki3AFhFv1om
# 51323  4QzJqjUhedncg4m9keRmz7dAjfb9Et8VfBcMEew5sA1U
# 47913  8bCQiauSvZjB2FSL83pVHMZrgfFbYY5ff7cdMUpz4FVq
# 95329  3gpyRVcdbH6Jy1AR5Xz5hypNGyGWECLXM5eaA79z4GdQ
# 84580  E5yLGHhe8PxughUVLRvFsc9ufcWviGRczW92moTGmzLJ
#
#                                                MINT  TOTAL_ADDED_LIQUIDITY  \
# 95256  DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263           2.287393e+12
# 95408  DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263           5.512326e+11
# 47606  4XgoqVmM4D3ts697pghaCZcK2JvsdA8JYCxc4aerZF2Y           6.859382e+10
# 29575  3UrGrYW8ampNzLbx8LP7HyKig27EapBA4TkFwoKiP5Kp           1.402633e+10
# 82222  GpLGcXFdL5evTKqZBWvM6p8yGCTWH9YnK3mk4kJZYpc7           2.184661e+14
# 11961  8RweLrRJ7kQ1Kk6Uqd3fs8Hees295p3CYa7yiycGH8Lw           5.000000e+14
# 51323  EpBksLwPFdf7SLcQ2oNh1HsNWfMudrTVvSbpAdMRXaUh           4.600553e+12
# 47913  5adgZL4TvU4GnaJ76g91up8AaLj7cqu3CvYyVXmSNPdb           6.602291e+10
# 95329  DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263           3.447080e+11
# 84580  F2wSK4m7jirMsBSJCrgct2iSU3BnGjGzbk7bs1X8QutG           1.000002e+12
#
#        TOTAL_REMOVED_LIQUIDITY  NUM_LIQUIDITY_ADDS  NUM_LIQUIDITY_REMOVES  \
# 95256             2.847503e+12            186415.0                87226.0
# 95408             6.739355e+11             92368.0                31211.0
# 47606             2.524209e+03                 6.0                    5.0
# 29575             1.611971e+02                 2.0                    1.0
# 82222             1.937779e+14                 8.0                  134.0
# 11961             5.000000e+14                 1.0                    1.0
# 51323             8.709849e+05                 2.0                    1.0
# 47913             3.229444e+03                 2.0                    1.0
# 95329             3.836464e+11             42380.0                29478.0
# 84580             1.000002e+12                 2.0                    2.0
#
#        ADD_TO_REMOVE_RATIO  LAST_POOL_ACTIVITY_TIMESTAMP_ts  \
# 95256         8.032978e-01                       1730418928
# 95408         8.179308e-01                       1730416655
# 47606         2.717439e+07                       1728870578
# 29575         8.701355e+07                       1728153341
# 82222         1.127405e+00                       1711494201
# 11961         1.000000e+00                       1727392728
# 51323         5.282012e+06                       1727253648
# 47913         2.044405e+07                       1728871018
# 95329         8.985044e-01                       1730410423
# 84580         1.000000e+00                       1706447191
#
#        FIRST_POOL_ACTIVITY_TIMESTAMP_ts  LAST_SWAP_TIMESTAMP_ts  ...  \
# 95256                        1704067581              1730419136  ...
# 95408                        1704067225              1730419136  ...
# 47606                        1717552481             -9223372037  ...
# 29575                        1721746718             -9223372037  ...
# 82222                        1707073198             -9223372037  ...
# 11961                        1727391322             -9223372037  ...
# 51323                        1716744101             -9223372037  ...
# 47913                        1717480275             -9223372037  ...
# 95329                        1704067431              1730419136  ...
# 84580                        1706445104             -9223372037  ...
#
#        FIRST_POOL_ACTIVITY_TIMESTAMP_weekday  \
# 95256                                    0.0
# 95408                                    0.0
# 47606                                    2.0
# 29575                                    1.0
# 82222                                    6.0
# 11961                                    3.0
# 51323                                    6.0
# 47913                                    1.0
# 95329                                    0.0
# 84580                                    6.0
#
#        FIRST_POOL_ACTIVITY_TIMESTAMP_month  LAST_SWAP_TIMESTAMP_hour  \
# 95256                                  1.0                      23.0
# 95408                                  1.0                      23.0
# 47606                                  6.0                      -1.0
# 29575                                  7.0                      -1.0
# 82222                                  2.0                      -1.0
# 11961                                  9.0                      -1.0
# 51323                                  5.0                      -1.0
# 47913                                  6.0                      -1.0
# 95329                                  1.0                      23.0
# 84580                                  1.0                      -1.0
#
#        LAST_SWAP_TIMESTAMP_day  LAST_SWAP_TIMESTAMP_weekday  \
# 95256                     31.0                          3.0
# 95408                     31.0                          3.0
# 47606                     -1.0                         -1.0
# 29575                     -1.0                         -1.0
# 82222                     -1.0                         -1.0
# 11961                     -1.0                         -1.0
# 51323                     -1.0                         -1.0
# 47913                     -1.0                         -1.0
# 95329                     31.0                          3.0
# 84580                     -1.0                         -1.0
#
#        LAST_SWAP_TIMESTAMP_month  INACTIVITY_STATUS_Active  \
# 95256                       10.0                      True
# 95408                       10.0                      True
# 47606                       -1.0                     False
# 29575                       -1.0                     False
# 82222                       -1.0                     False
# 11961                       -1.0                     False
# 51323                       -1.0                     False
# 47913                       -1.0                     False
# 95329                       10.0                      True
# 84580                       -1.0                     False
#
#        INACTIVITY_STATUS_Inactive  anomaly_score_isolation_forest  \
# 95256                       False                       -0.105200
# 95408                       False                       -0.095028
# 47606                        True                       -0.094040
# 29575                        True                       -0.084491
# 82222                        True                       -0.082691
# 11961                        True                       -0.081800
# 51323                        True                       -0.081710
# 47913                        True                       -0.080950
# 95329                       False                       -0.079850
# 84580                        True                       -0.076955
#
#        is_outlier_isolation_forest
# 95256                           -1
# 95408                           -1
# 47606                           -1
# 29575                           -1
# 82222                           -1
# 11961                           -1
# 51323                           -1
# 47913                           -1
# 95329                           -1
# 84580                           -1
#
# [10 rows x 26 columns]
#
# Số lượng điểm được dự đoán là outliers: 478
# Thông tin về các điểm được dự đoán là outliers:
#                              LIQUIDITY_POOL_ADDRESS  \
# 4028   9p4LGr6oAHWie8A8QGtS1BZUyBRvCBezo9uj8Fpbg9g4
# 4618    TDqw2ERGMAZgAhpgH1RA9mRGuFyzJxn2fiYbPJZPRVH
# 7400   7CvWY12ikyG2RX2r3YtajY88bMwCG7dHLiiumpPYegsv
# 10671  7kC4F6CLeAC3TU9RmZfmE2aJ3afeBR1QMVEGNt8cnqyt
# 10721  AuA7vMPLRi4cukZt18fqvBEuuQtmgw3Wsvi9A4z7MVro
#
#                                                MINT  TOTAL_ADDED_LIQUIDITY  \
# 4028   CgFdo4U7Vd1PviMM2yvbhVpaZDVtaxwVA6m8Z3vdArJx           9.000000e+09
# 4618   3Vse7Heee7Yb3U95vjQXDHqDBor6ERNQrA88GjeSVVj3           1.000000e+10
# 7400   FCTD4vHdWesmAqapE8r95yKUkrdZ7PFZbzD9UPigbL6z           6.475591e+13
# 10671  Gc2EPZgZ1AiPGDCM8P1q5wE1RUCbAMhEhXNxqhNfTnGm           7.178365e+11
# 10721  8v9aqi59YsdXtDfwb7iB5oVVpS3MdnMhuWmkkb1aiTmF           6.839216e+12
#
#        TOTAL_REMOVED_LIQUIDITY  NUM_LIQUIDITY_ADDS  NUM_LIQUIDITY_REMOVES  \
# 4028              9.000000e+09                 1.0                    2.0
# 4618              5.027987e+00                 2.0                    1.0
# 7400              6.475591e+13                 1.0                    1.0
# 10671             2.043266e+12                 1.0                    1.0
# 10721             6.102393e+12                 1.0                    1.0
#
#        ADD_TO_REMOVE_RATIO  LAST_POOL_ACTIVITY_TIMESTAMP_ts  \
# 4028          1.000000e+00                       1729473076
# 4618          1.988868e+09                       1729376656
# 7400          1.000000e+00                       1729293334
# 10671         3.513183e-01                       1727868123
# 10721         1.120743e+00                       1728225484
#
#        FIRST_POOL_ACTIVITY_TIMESTAMP_ts  LAST_SWAP_TIMESTAMP_ts  ...  \
# 4028                         1729449831             -9223372037  ...
# 4618                         1729328484              1729414796  ...
# 7400                         1728709902              1724438040  ...
# 10671                        1727751805              1727754138  ...
# 10721                        1727735942              1729762160  ...
#
#        FIRST_POOL_ACTIVITY_TIMESTAMP_weekday  \
# 4028                                     6.0
# 4618                                     5.0
# 7400                                     5.0
# 10671                                    1.0
# 10721                                    0.0
#
#        FIRST_POOL_ACTIVITY_TIMESTAMP_month  LAST_SWAP_TIMESTAMP_hour  \
# 4028                                  10.0                      -1.0
# 4618                                  10.0                       8.0
# 7400                                  10.0                      18.0
# 10671                                 10.0                       3.0
# 10721                                  9.0                       9.0
#
#        LAST_SWAP_TIMESTAMP_day  LAST_SWAP_TIMESTAMP_weekday  \
# 4028                      -1.0                         -1.0
# 4618                      20.0                          6.0
# 7400                      23.0                          4.0
# 10671                      1.0                          1.0
# 10721                     24.0                          3.0
#
#        LAST_SWAP_TIMESTAMP_month  INACTIVITY_STATUS_Active  \
# 4028                        -1.0                     False
# 4618                        10.0                     False
# 7400                         8.0                     False
# 10671                       10.0                     False
# 10721                       10.0                     False
#
#        INACTIVITY_STATUS_Inactive  anomaly_score_isolation_forest  \
# 4028                         True                       -0.023777
# 4618                         True                       -0.050223
# 7400                         True                       -0.022301
# 10671                        True                       -0.010341
# 10721                        True                       -0.039311
#
#        is_outlier_isolation_forest
# 4028                            -1
# 4618                            -1
# 7400                            -1
# 10671                           -1
# 10721                           -1
#
# [5 rows x 26 columns]

# %%
anomaly_candidates_df = df[df['is_outlier_isolation_forest'] == -1]
anomaly_candidates_df.head(1).to_dict()
# Out:
# {'LIQUIDITY_POOL_ADDRESS': {4028: '9p4LGr6oAHWie8A8QGtS1BZUyBRvCBezo9uj8Fpbg9g4'},
#  'MINT': {4028: 'CgFdo4U7Vd1PviMM2yvbhVpaZDVtaxwVA6m8Z3vdArJx'},
#  'TOTAL_ADDED_LIQUIDITY': {4028: 9000000000.0},
#  'TOTAL_REMOVED_LIQUIDITY': {4028: 8999999992.5078},
#  'NUM_LIQUIDITY_ADDS': {4028: 1.0},
#  'NUM_LIQUIDITY_REMOVES': {4028: 2.0},
#  'ADD_TO_REMOVE_RATIO': {4028: 1.000000001},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_ts': {4028: 1729473076},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': {4028: 1729449831},
#  'LAST_SWAP_TIMESTAMP_ts': {4028: -9223372037},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_hour': {4028: 1.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_day': {4028: 21.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': {4028: 0.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_month': {4028: 10.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': {4028: 18.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_day': {4028: 20.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': {4028: 6.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_month': {4028: 10.0},
#  'LAST_SWAP_TIMESTAMP_hour': {4028: -1.0},
#  'LAST_SWAP_TIMESTAMP_day': {4028: -1.0},
#  'LAST_SWAP_TIMESTAMP_weekday': {4028: -1.0},
#  'LAST_SWAP_TIMESTAMP_month': {4028: -1.0},
#  'INACTIVITY_STATUS_Active': {4028: False},
#  'INACTIVITY_STATUS_Inactive': {4028: True},
#  'anomaly_score_isolation_forest': {4028: -0.023776912060618938},
#  'is_outlier_isolation_forest': {4028: -1}}

# %%
subset_to_label = df.sort_values(by='anomaly_score_isolation_forest').head(478)
indices_to_label = subset_to_label.index

# %%
df['true_label'] = np.nan

# %%
import joblib
import os 
output_dir = '/kaggle/working/'

model_filename = 'isolation_forest_model.joblib'

#save model
output_path = os.path.join(output_dir, model_filename)
print(f"Saving model to: {output_path}")
joblib.dump(best_model, output_path)
print("Saving model successfully.")

# Save scaler
scaler_filename = "scaler.pkl"
scaler_output_path = os.path.join(output_dir, scaler_filename)
print(f"Saving scaler to: {scaler_output_path}")
joblib.dump(scaler, scaler_output_path)
print("Saving scaler successfully.")
# Out:
# Saving model to: /kaggle/working/isolation_forest_model.joblib
# Saving model successfully.
# Saving scaler to: /kaggle/working/scaler.pkl
# Saving scaler successfully.

# %%
subset_to_label.head(10).to_dict()
# Out:
# {'LIQUIDITY_POOL_ADDRESS': {95256: '3ne4mWqdYuNiYrYZC9TrA3FcfuFdErghH97vNPbjicr1',
#   95408: '8QaXeHBrShJTdtN1rWCccBxpSVvKksQ2PCu5nufb2zbk',
#   47606: 'Fptmpk3UW6KcVTFFpoWv53eiji8dn2jVaZDNhHEhxCYy',
#   29575: '7sJ6qfKZvSNqSSPJKTVZBww21SQuAr5CDy8TUzNPjG6b',
#   82222: '4sq2VviSRTNDg1Fdm1VzbbeCWgkqFJtWWAqHhfAYFrXs',
#   11961: '5no8Tr7WBcXjTEwtLa6MVuzFvL6Liv1rnki3AFhFv1om',
#   51323: '4QzJqjUhedncg4m9keRmz7dAjfb9Et8VfBcMEew5sA1U',
#   47913: '8bCQiauSvZjB2FSL83pVHMZrgfFbYY5ff7cdMUpz4FVq',
#   95329: '3gpyRVcdbH6Jy1AR5Xz5hypNGyGWECLXM5eaA79z4GdQ',
#   84580: 'E5yLGHhe8PxughUVLRvFsc9ufcWviGRczW92moTGmzLJ'},
#  'MINT': {95256: 'DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263',
#   95408: 'DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263',
#   47606: '4XgoqVmM4D3ts697pghaCZcK2JvsdA8JYCxc4aerZF2Y',
#   29575: '3UrGrYW8ampNzLbx8LP7HyKig27EapBA4TkFwoKiP5Kp',
#   82222: 'GpLGcXFdL5evTKqZBWvM6p8yGCTWH9YnK3mk4kJZYpc7',
#   11961: '8RweLrRJ7kQ1Kk6Uqd3fs8Hees295p3CYa7yiycGH8Lw',
#   51323: 'EpBksLwPFdf7SLcQ2oNh1HsNWfMudrTVvSbpAdMRXaUh',
#   47913: '5adgZL4TvU4GnaJ76g91up8AaLj7cqu3CvYyVXmSNPdb',
#   95329: 'DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263',
#   84580: 'F2wSK4m7jirMsBSJCrgct2iSU3BnGjGzbk7bs1X8QutG'},
#  'TOTAL_ADDED_LIQUIDITY': {95256: 2287393143117.23,
#   95408: 551232554537.91,
#   47606: 68593822519.1516,
#   29575: 14026333456.1265,
#   82222: 218466113983500.0,
#   11961: 499999999999997.0,
#   51323: 4600552538943.01,
#   47913: 66022910039.2474,
#   95329: 344707978355.007,
#   84580: 1000001655971.15},
#  'TOTAL_REMOVED_LIQUIDITY': {95256: 2847503355904.54,
#   95408: 673935469012.2,
#   47606: 2524.208505,
#   29575: 161.197109,
#   82222: 193777880726481.0,
#   11961: 499999999999997.0,
#   51323: 870984.891,
#   47913: 3229.443534,
#   95329: 383646416574.815,
#   84580: 1000001655971.15},
#  'NUM_LIQUIDITY_ADDS': {95256: 186415.0,
#   95408: 92368.0,
#   47606: 6.0,
#   29575: 2.0,
#   82222: 8.0,
#   11961: 1.0,
#   51323: 2.0,
#   47913: 2.0,
#   95329: 42380.0,
#   84580: 2.0},
#  'NUM_LIQUIDITY_REMOVES': {95256: 87226.0,
#   95408: 31211.0,
#   47606: 5.0,
#   29575: 1.0,
#   82222: 134.0,
#   11961: 1.0,
#   51323: 1.0,
#   47913: 1.0,
#   95329: 29478.0,
#   84580: 2.0},
#  'ADD_TO_REMOVE_RATIO': {95256: 0.8032977866,
#   95408: 0.8179307662,
#   47606: 27174388.4799055,
#   29575: 87013554.6669546,
#   82222: 1.127404806,
#   11961: 1.0,
#   51323: 5282011.87699249,
#   47913: 20444051.5352412,
#   95329: 0.8985043609,
#   84580: 1.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_ts': {95256: 1730418928,
#   95408: 1730416655,
#   47606: 1728870578,
#   29575: 1728153341,
#   82222: 1711494201,
#   11961: 1727392728,
#   51323: 1727253648,
#   47913: 1728871018,
#   95329: 1730410423,
#   84580: 1706447191},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': {95256: 1704067581,
#   95408: 1704067225,
#   47606: 1717552481,
#   29575: 1721746718,
#   82222: 1707073198,
#   11961: 1727391322,
#   51323: 1716744101,
#   47913: 1717480275,
#   95329: 1704067431,
#   84580: 1706445104},
#  'LAST_SWAP_TIMESTAMP_ts': {95256: 1730419136,
#   95408: 1730419136,
#   47606: -9223372037,
#   29575: -9223372037,
#   82222: -9223372037,
#   11961: -9223372037,
#   51323: -9223372037,
#   47913: -9223372037,
#   95329: 1730419136,
#   84580: -9223372037},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_hour': {95256: 23.0,
#   95408: 23.0,
#   47606: 1.0,
#   29575: 18.0,
#   82222: 23.0,
#   11961: 23.0,
#   51323: 8.0,
#   47913: 1.0,
#   95329: 21.0,
#   84580: 13.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_day': {95256: 31.0,
#   95408: 31.0,
#   47606: 14.0,
#   29575: 5.0,
#   82222: 26.0,
#   11961: 26.0,
#   51323: 25.0,
#   47913: 14.0,
#   95329: 31.0,
#   84580: 28.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': {95256: 3.0,
#   95408: 3.0,
#   47606: 0.0,
#   29575: 5.0,
#   82222: 1.0,
#   11961: 3.0,
#   51323: 2.0,
#   47913: 0.0,
#   95329: 3.0,
#   84580: 6.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_month': {95256: 10.0,
#   95408: 10.0,
#   47606: 10.0,
#   29575: 10.0,
#   82222: 3.0,
#   11961: 9.0,
#   51323: 9.0,
#   47913: 10.0,
#   95329: 10.0,
#   84580: 1.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': {95256: 0.0,
#   95408: 0.0,
#   47606: 1.0,
#   29575: 14.0,
#   82222: 18.0,
#   11961: 22.0,
#   51323: 17.0,
#   47913: 5.0,
#   95329: 0.0,
#   84580: 12.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_day': {95256: 1.0,
#   95408: 1.0,
#   47606: 5.0,
#   29575: 23.0,
#   82222: 4.0,
#   11961: 26.0,
#   51323: 26.0,
#   47913: 4.0,
#   95329: 1.0,
#   84580: 28.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': {95256: 0.0,
#   95408: 0.0,
#   47606: 2.0,
#   29575: 1.0,
#   82222: 6.0,
#   11961: 3.0,
#   51323: 6.0,
#   47913: 1.0,
#   95329: 0.0,
#   84580: 6.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_month': {95256: 1.0,
#   95408: 1.0,
#   47606: 6.0,
#   29575: 7.0,
#   82222: 2.0,
#   11961: 9.0,
#   51323: 5.0,
#   47913: 6.0,
#   95329: 1.0,
#   84580: 1.0},
#  'LAST_SWAP_TIMESTAMP_hour': {95256: 23.0,
#   95408: 23.0,
#   47606: -1.0,
#   29575: -1.0,
#   82222: -1.0,
#   11961: -1.0,
#   51323: -1.0,
#   47913: -1.0,
#   95329: 23.0,
#   84580: -1.0},
#  'LAST_SWAP_TIMESTAMP_day': {95256: 31.0,
#   95408: 31.0,
#   47606: -1.0,
#   29575: -1.0,
#   82222: -1.0,
#   11961: -1.0,
#   51323: -1.0,
#   47913: -1.0,
#   95329: 31.0,
#   84580: -1.0},
#  'LAST_SWAP_TIMESTAMP_weekday': {95256: 3.0,
#   95408: 3.0,
#   47606: -1.0,
#   29575: -1.0,
#   82222: -1.0,
#   11961: -1.0,
#   51323: -1.0,
#   47913: -1.0,
#   95329: 3.0,
#   84580: -1.0},
#  'LAST_SWAP_TIMESTAMP_month': {95256: 10.0,
#   95408: 10.0,
#   47606: -1.0,
#   29575: -1.0,
#   82222: -1.0,
#   11961: -1.0,
#   51323: -1.0,
#   47913: -1.0,
#   95329: 10.0,
#   84580: -1.0},
#  'INACTIVITY_STATUS_Active': {95256: True,
#   95408: True,
#   47606: False,
#   29575: False,
#   82222: False,
#   11961: False,
#   51323: False,
#   47913: False,
#   95329: True,
#   84580: False},
#  'INACTIVITY_STATUS_Inactive': {95256: False,
#   95408: False,
#   47606: True,
#   29575: True,
#   82222: True,
#   11961: True,
#   51323: True,
#   47913: True,
#   95329: False,
#   84580: True},
#  'anomaly_score_isolation_forest': {95256: -0.10519966509325396,
#   95408: -0.09502766394012085,
#   47606: -0.09404021486017489,
#   29575: -0.08449071673104913,
#   82222: -0.0826910877492143,
#   11961: -0.08180017561246344,
#   51323: -0.0817100807400094,
#   47913: -0.08094968068212904,
#   95329: -0.07985049926687326,
#   84580: -0.0769549778991313},
#  'is_outlier_isolation_forest': {95256: -1,
#   95408: -1,
#   47606: -1,
#   29575: -1,
#   82222: -1,
#   11961: -1,
#   51323: -1,
#   47913: -1,
#   95329: -1,
#   84580: -1}}

# %%
for i, row in subset_to_label.head(30).iterrows():
    print(f"Index: {i}, Data: {row.to_dict()}")
# Out:
# Index: 95256, Data: {'LIQUIDITY_POOL_ADDRESS': '3ne4mWqdYuNiYrYZC9TrA3FcfuFdErghH97vNPbjicr1', 'MINT': 'DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263', 'TOTAL_ADDED_LIQUIDITY': 2287393143117.23, 'TOTAL_REMOVED_LIQUIDITY': 2847503355904.54, 'NUM_LIQUIDITY_ADDS': 186415.0, 'NUM_LIQUIDITY_REMOVES': 87226.0, 'ADD_TO_REMOVE_RATIO': 0.8032977866, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1730418928, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704067581, 'LAST_SWAP_TIMESTAMP_ts': 1730419136, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 23.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 31.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 23.0, 'LAST_SWAP_TIMESTAMP_day': 31.0, 'LAST_SWAP_TIMESTAMP_weekday': 3.0, 'LAST_SWAP_TIMESTAMP_month': 10.0, 'INACTIVITY_STATUS_Active': True, 'INACTIVITY_STATUS_Inactive': False, 'anomaly_score_isolation_forest': -0.10519966509325396, 'is_outlier_isolation_forest': -1}
# Index: 95408, Data: {'LIQUIDITY_POOL_ADDRESS': '8QaXeHBrShJTdtN1rWCccBxpSVvKksQ2PCu5nufb2zbk', 'MINT': 'DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263', 'TOTAL_ADDED_LIQUIDITY': 551232554537.91, 'TOTAL_REMOVED_LIQUIDITY': 673935469012.2, 'NUM_LIQUIDITY_ADDS': 92368.0, 'NUM_LIQUIDITY_REMOVES': 31211.0, 'ADD_TO_REMOVE_RATIO': 0.8179307662, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1730416655, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704067225, 'LAST_SWAP_TIMESTAMP_ts': 1730419136, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 23.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 31.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 23.0, 'LAST_SWAP_TIMESTAMP_day': 31.0, 'LAST_SWAP_TIMESTAMP_weekday': 3.0, 'LAST_SWAP_TIMESTAMP_month': 10.0, 'INACTIVITY_STATUS_Active': True, 'INACTIVITY_STATUS_Inactive': False, 'anomaly_score_isolation_forest': -0.09502766394012085, 'is_outlier_isolation_forest': -1}
# Index: 47606, Data: {'LIQUIDITY_POOL_ADDRESS': 'Fptmpk3UW6KcVTFFpoWv53eiji8dn2jVaZDNhHEhxCYy', 'MINT': '4XgoqVmM4D3ts697pghaCZcK2JvsdA8JYCxc4aerZF2Y', 'TOTAL_ADDED_LIQUIDITY': 68593822519.1516, 'TOTAL_REMOVED_LIQUIDITY': 2524.208505, 'NUM_LIQUIDITY_ADDS': 6.0, 'NUM_LIQUIDITY_REMOVES': 5.0, 'ADD_TO_REMOVE_RATIO': 27174388.4799055, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1728870578, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1717552481, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 6.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.09404021486017489, 'is_outlier_isolation_forest': -1}
# Index: 29575, Data: {'LIQUIDITY_POOL_ADDRESS': '7sJ6qfKZvSNqSSPJKTVZBww21SQuAr5CDy8TUzNPjG6b', 'MINT': '3UrGrYW8ampNzLbx8LP7HyKig27EapBA4TkFwoKiP5Kp', 'TOTAL_ADDED_LIQUIDITY': 14026333456.1265, 'TOTAL_REMOVED_LIQUIDITY': 161.197109, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 87013554.6669546, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1728153341, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1721746718, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 18.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 5.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 5.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 14.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 23.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 7.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.08449071673104913, 'is_outlier_isolation_forest': -1}
# Index: 82222, Data: {'LIQUIDITY_POOL_ADDRESS': '4sq2VviSRTNDg1Fdm1VzbbeCWgkqFJtWWAqHhfAYFrXs', 'MINT': 'GpLGcXFdL5evTKqZBWvM6p8yGCTWH9YnK3mk4kJZYpc7', 'TOTAL_ADDED_LIQUIDITY': 218466113983500.0, 'TOTAL_REMOVED_LIQUIDITY': 193777880726481.0, 'NUM_LIQUIDITY_ADDS': 8.0, 'NUM_LIQUIDITY_REMOVES': 134.0, 'ADD_TO_REMOVE_RATIO': 1.127404806, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1711494201, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1707073198, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 23.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 3.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 18.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 4.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 2.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.0826910877492143, 'is_outlier_isolation_forest': -1}
# Index: 11961, Data: {'LIQUIDITY_POOL_ADDRESS': '5no8Tr7WBcXjTEwtLa6MVuzFvL6Liv1rnki3AFhFv1om', 'MINT': '8RweLrRJ7kQ1Kk6Uqd3fs8Hees295p3CYa7yiycGH8Lw', 'TOTAL_ADDED_LIQUIDITY': 499999999999997.0, 'TOTAL_REMOVED_LIQUIDITY': 499999999999997.0, 'NUM_LIQUIDITY_ADDS': 1.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1727392728, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1727391322, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 23.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 9.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 22.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 9.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.08180017561246344, 'is_outlier_isolation_forest': -1}
# Index: 51323, Data: {'LIQUIDITY_POOL_ADDRESS': '4QzJqjUhedncg4m9keRmz7dAjfb9Et8VfBcMEew5sA1U', 'MINT': 'EpBksLwPFdf7SLcQ2oNh1HsNWfMudrTVvSbpAdMRXaUh', 'TOTAL_ADDED_LIQUIDITY': 4600552538943.01, 'TOTAL_REMOVED_LIQUIDITY': 870984.891, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 5282011.87699249, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1727253648, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1716744101, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 8.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 25.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 2.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 9.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 17.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 5.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.0817100807400094, 'is_outlier_isolation_forest': -1}
# Index: 47913, Data: {'LIQUIDITY_POOL_ADDRESS': '8bCQiauSvZjB2FSL83pVHMZrgfFbYY5ff7cdMUpz4FVq', 'MINT': '5adgZL4TvU4GnaJ76g91up8AaLj7cqu3CvYyVXmSNPdb', 'TOTAL_ADDED_LIQUIDITY': 66022910039.2474, 'TOTAL_REMOVED_LIQUIDITY': 3229.443534, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 20444051.5352412, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1728871018, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1717480275, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 4.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 6.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.08094968068212904, 'is_outlier_isolation_forest': -1}
# Index: 95329, Data: {'LIQUIDITY_POOL_ADDRESS': '3gpyRVcdbH6Jy1AR5Xz5hypNGyGWECLXM5eaA79z4GdQ', 'MINT': 'DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263', 'TOTAL_ADDED_LIQUIDITY': 344707978355.007, 'TOTAL_REMOVED_LIQUIDITY': 383646416574.815, 'NUM_LIQUIDITY_ADDS': 42380.0, 'NUM_LIQUIDITY_REMOVES': 29478.0, 'ADD_TO_REMOVE_RATIO': 0.8985043609, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1730410423, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704067431, 'LAST_SWAP_TIMESTAMP_ts': 1730419136, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 21.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 31.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 23.0, 'LAST_SWAP_TIMESTAMP_day': 31.0, 'LAST_SWAP_TIMESTAMP_weekday': 3.0, 'LAST_SWAP_TIMESTAMP_month': 10.0, 'INACTIVITY_STATUS_Active': True, 'INACTIVITY_STATUS_Inactive': False, 'anomaly_score_isolation_forest': -0.07985049926687326, 'is_outlier_isolation_forest': -1}
# Index: 84580, Data: {'LIQUIDITY_POOL_ADDRESS': 'E5yLGHhe8PxughUVLRvFsc9ufcWviGRczW92moTGmzLJ', 'MINT': 'F2wSK4m7jirMsBSJCrgct2iSU3BnGjGzbk7bs1X8QutG', 'TOTAL_ADDED_LIQUIDITY': 1000001655971.15, 'TOTAL_REMOVED_LIQUIDITY': 1000001655971.15, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 2.0, 'ADD_TO_REMOVE_RATIO': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1706447191, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1706445104, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 13.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 28.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 12.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 28.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.0769549778991313, 'is_outlier_isolation_forest': -1}
# Index: 93561, Data: {'LIQUIDITY_POOL_ADDRESS': 'Fq7jPefUJ4Z4exE7QsBzrWK7cfqxKW8XazNwQ5akGwBz', 'MINT': 'LFG1ezantSY2LPX8jRz2qa31pPEhpwN9msFDzZw4T9Q', 'TOTAL_ADDED_LIQUIDITY': 1680411695398.66, 'TOTAL_REMOVED_LIQUIDITY': 1758022391013.92, 'NUM_LIQUIDITY_ADDS': 34089.0, 'NUM_LIQUIDITY_REMOVES': 69715.0, 'ADD_TO_REMOVE_RATIO': 0.9558534089, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1730375505, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704139437, 'LAST_SWAP_TIMESTAMP_ts': 1730418851, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 11.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 31.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 20.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 23.0, 'LAST_SWAP_TIMESTAMP_day': 31.0, 'LAST_SWAP_TIMESTAMP_weekday': 3.0, 'LAST_SWAP_TIMESTAMP_month': 10.0, 'INACTIVITY_STATUS_Active': True, 'INACTIVITY_STATUS_Inactive': False, 'anomaly_score_isolation_forest': -0.07690207349922062, 'is_outlier_isolation_forest': -1}
# Index: 92245, Data: {'LIQUIDITY_POOL_ADDRESS': '8NrkeHEzMawZaEurxF4QFBxcQ7jUpyUbM8qPxGjCMUzq', 'MINT': '94sFWT94hg6qK9VtYwGz8VxbyEMaXf9H2U3HTTbofimy', 'TOTAL_ADDED_LIQUIDITY': 63170513479833.3, 'TOTAL_REMOVED_LIQUIDITY': 40865722366169.7, 'NUM_LIQUIDITY_ADDS': 1042.0, 'NUM_LIQUIDITY_REMOVES': 6393.0, 'ADD_TO_REMOVE_RATIO': 1.545806848, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1729593956, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704314894, 'LAST_SWAP_TIMESTAMP_ts': 1729632360, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 10.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 22.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 20.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 3.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 21.0, 'LAST_SWAP_TIMESTAMP_day': 22.0, 'LAST_SWAP_TIMESTAMP_weekday': 1.0, 'LAST_SWAP_TIMESTAMP_month': 10.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.07645442583171302, 'is_outlier_isolation_forest': -1}
# Index: 85131, Data: {'LIQUIDITY_POOL_ADDRESS': 'EgCwqWCXVzETY2zEUffn7ZaCbyBtsHCzfYfZBBd5igkn', 'MINT': '5ovWbyonBsts6kWsS49v5H3aDL61u8ahGGCSiWJhdoLp', 'TOTAL_ADDED_LIQUIDITY': 3418771220095670.0, 'TOTAL_REMOVED_LIQUIDITY': 1768401799313.26, 'NUM_LIQUIDITY_ADDS': 8.0, 'NUM_LIQUIDITY_REMOVES': 4.0, 'ADD_TO_REMOVE_RATIO': 1933.254773561, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1706392536, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1706297205, 'LAST_SWAP_TIMESTAMP_ts': 1712101672, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 21.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 27.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 5.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 19.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 4.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 23.0, 'LAST_SWAP_TIMESTAMP_day': 2.0, 'LAST_SWAP_TIMESTAMP_weekday': 1.0, 'LAST_SWAP_TIMESTAMP_month': 4.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.07509310358794596, 'is_outlier_isolation_forest': -1}
# Index: 84726, Data: {'LIQUIDITY_POOL_ADDRESS': 'BmHuXoh9xG1FxK3GFqDAaamv5vnvXpEHzS1odccpMgGL', 'MINT': '52QaBoDMTKTZBoGT7jZgpjpHJq5v4r1mEPH641q8V1Zg', 'TOTAL_ADDED_LIQUIDITY': 129871219592.476, 'TOTAL_REMOVED_LIQUIDITY': 129871219592.476, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 2.0, 'ADD_TO_REMOVE_RATIO': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1706401947, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1706401087, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 28.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 28.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.07322968738286217, 'is_outlier_isolation_forest': -1}
# Index: 95081, Data: {'LIQUIDITY_POOL_ADDRESS': 'HrXPdUiPbzof3yPBb2wdB9ryhRSEe2hKhzpfpPMQbnRZ', 'MINT': 'AZsHEMXd36Bj1EMNXhowJajpUXzrKcK57wW4ZGXVa7yR', 'TOTAL_ADDED_LIQUIDITY': 9851161410943.29, 'TOTAL_REMOVED_LIQUIDITY': 12530611003043.7, 'NUM_LIQUIDITY_ADDS': 37930.0, 'NUM_LIQUIDITY_REMOVES': 11898.0, 'ADD_TO_REMOVE_RATIO': 0.7861676824, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1730414538, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704068403, 'LAST_SWAP_TIMESTAMP_ts': 1730416972, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 22.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 31.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 23.0, 'LAST_SWAP_TIMESTAMP_day': 31.0, 'LAST_SWAP_TIMESTAMP_weekday': 3.0, 'LAST_SWAP_TIMESTAMP_month': 10.0, 'INACTIVITY_STATUS_Active': True, 'INACTIVITY_STATUS_Inactive': False, 'anomaly_score_isolation_forest': -0.07250265244318299, 'is_outlier_isolation_forest': -1}
# Index: 27784, Data: {'LIQUIDITY_POOL_ADDRESS': '5884r4EQrNVVTaMiK3q8H8DtQmMzpSKAUJ1aMd6LBSB4', 'MINT': 'Fki6kDSRL4PRBw7sSVKQTXbiRfshEqsUqqvypiPJEH5f', 'TOTAL_ADDED_LIQUIDITY': 3615745961.76045, 'TOTAL_REMOVED_LIQUIDITY': 172.216945, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 20995297.3080579, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1729755577, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1722109728, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 7.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 24.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 19.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 27.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 7.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.07247581575999751, 'is_outlier_isolation_forest': -1}
# Index: 50063, Data: {'LIQUIDITY_POOL_ADDRESS': '2PfJD5aKpzqBGPGduN8z9NGcZxcygAkkzneGS1vpJjCe', 'MINT': '7Emb92dbMEbsbRcePc8YqxSRcHCrWrgHgMLiDJ5XrECY', 'TOTAL_ADDED_LIQUIDITY': 25001278978.0665, 'TOTAL_REMOVED_LIQUIDITY': 3307.036648, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 7560024.77117591, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1727253786, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1716988571, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 8.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 25.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 2.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 9.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 13.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 29.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 5.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.07215772708020651, 'is_outlier_isolation_forest': -1}
# Index: 95359, Data: {'LIQUIDITY_POOL_ADDRESS': '8EyL9NRDo8DfE5rywgnu8KFfm8P7MjYT8wjNUQyGwst8', 'MINT': 'mb1eu7TzEc71KxDpsmsKoucSSuuoGLv1drys1oP2jh6', 'TOTAL_ADDED_LIQUIDITY': 51107561152.0388, 'TOTAL_REMOVED_LIQUIDITY': 51750277832.0872, 'NUM_LIQUIDITY_ADDS': 22252.0, 'NUM_LIQUIDITY_REMOVES': 32009.0, 'ADD_TO_REMOVE_RATIO': 0.9875804207, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1730417676, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704067356, 'LAST_SWAP_TIMESTAMP_ts': 1730418166, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 23.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 31.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 23.0, 'LAST_SWAP_TIMESTAMP_day': 31.0, 'LAST_SWAP_TIMESTAMP_weekday': 3.0, 'LAST_SWAP_TIMESTAMP_month': 10.0, 'INACTIVITY_STATUS_Active': True, 'INACTIVITY_STATUS_Inactive': False, 'anomaly_score_isolation_forest': -0.0709759163985827, 'is_outlier_isolation_forest': -1}
# Index: 82756, Data: {'LIQUIDITY_POOL_ADDRESS': '95rearCVnMKa7hfBC8R6NLaN5Kw1xxBSruG1eX33VsA4', 'MINT': '7vNuRmaESRCKNGaxb5kHhszDxTSdmyEhNR6n2nEehKyF', 'TOTAL_ADDED_LIQUIDITY': 999999999999.997, 'TOTAL_REMOVED_LIQUIDITY': 999999999999.997, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 4.0, 'ADD_TO_REMOVE_RATIO': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1706922659, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1706920217, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 5.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 3.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 2.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.07062524051479957, 'is_outlier_isolation_forest': -1}
# Index: 84170, Data: {'LIQUIDITY_POOL_ADDRESS': 'BrMYU1XWCqMAtBURD8yp3d9gni3uHxomoj5JG9LWr7Mj', 'MINT': 'DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263', 'TOTAL_ADDED_LIQUIDITY': 1157197180210.9, 'TOTAL_REMOVED_LIQUIDITY': 981872742294.657, 'NUM_LIQUIDITY_ADDS': 38851.0, 'NUM_LIQUIDITY_REMOVES': 22393.0, 'ADD_TO_REMOVE_RATIO': 1.178561264, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1730321576, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1706563268, 'LAST_SWAP_TIMESTAMP_ts': 1730419136, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 20.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 30.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 2.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 21.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 29.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 23.0, 'LAST_SWAP_TIMESTAMP_day': 31.0, 'LAST_SWAP_TIMESTAMP_weekday': 3.0, 'LAST_SWAP_TIMESTAMP_month': 10.0, 'INACTIVITY_STATUS_Active': True, 'INACTIVITY_STATUS_Inactive': False, 'anomaly_score_isolation_forest': -0.07054557863940014, 'is_outlier_isolation_forest': -1}
# Index: 85149, Data: {'LIQUIDITY_POOL_ADDRESS': '2NbYW9NUVufMHKnuCM1mpmeTysHEGAcHq3EDL85kqi8w', 'MINT': '5ovWbyonBsts6kWsS49v5H3aDL61u8ahGGCSiWJhdoLp', 'TOTAL_ADDED_LIQUIDITY': 3607843703705510.0, 'TOTAL_REMOVED_LIQUIDITY': 1257636386632490.0, 'NUM_LIQUIDITY_ADDS': 6.0, 'NUM_LIQUIDITY_REMOVES': 8.0, 'ADD_TO_REMOVE_RATIO': 2.868749459, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1706296585, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1706293891, 'LAST_SWAP_TIMESTAMP_ts': 1712101672, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 19.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 4.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 18.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 4.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 23.0, 'LAST_SWAP_TIMESTAMP_day': 2.0, 'LAST_SWAP_TIMESTAMP_weekday': 1.0, 'LAST_SWAP_TIMESTAMP_month': 4.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06940944566829366, 'is_outlier_isolation_forest': -1}
# Index: 91575, Data: {'LIQUIDITY_POOL_ADDRESS': '137Wy4xiPi6j7ssUaowH2DVg972Juf4btmg6p8LfgsnH', 'MINT': '23h3L2UxzdsmWntfAGJQNcFZ7iQb5sgzMR2JbaoduCmc', 'TOTAL_ADDED_LIQUIDITY': 70907372981422.9, 'TOTAL_REMOVED_LIQUIDITY': 67307125634181.2, 'NUM_LIQUIDITY_ADDS': 10.0, 'NUM_LIQUIDITY_REMOVES': 40.0, 'ADD_TO_REMOVE_RATIO': 1.053489839, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1705254323, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704467868, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 17.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 15.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 4.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06877782284801959, 'is_outlier_isolation_forest': -1}
# Index: 55636, Data: {'LIQUIDITY_POOL_ADDRESS': 'BAxJwA7FMcHjmZVwFp2a1sGqKu6b8npJZovD4rEM4TkK', 'MINT': '8exuywH7jW6AXBAb9f878uddLpPHjJFtNTxjZCjW4L3J', 'TOTAL_ADDED_LIQUIDITY': 34468110069736.2, 'TOTAL_REMOVED_LIQUIDITY': 321148468.190506, 'NUM_LIQUIDITY_ADDS': 4.0, 'NUM_LIQUIDITY_REMOVES': 4.0, 'ADD_TO_REMOVE_RATIO': 107327.648996568, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1718043620, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1715647495, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 18.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 10.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 5.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.0687476920459732, 'is_outlier_isolation_forest': -1}
# Index: 27232, Data: {'LIQUIDITY_POOL_ADDRESS': 'FHdK4NDhkwA37mbHztMeu3qff6MQVDxcMArEVJAeDBew', 'MINT': '7GVKxVoGKAdrQiZPtPDP8561zVG6SZ7HWcLzbZBSBoXW', 'TOTAL_ADDED_LIQUIDITY': 1693429278.74277, 'TOTAL_REMOVED_LIQUIDITY': 431.992669, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 3920041.7050197, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1729223668, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1722191685, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 18.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 4.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 18.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 28.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 7.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06744704048295314, 'is_outlier_isolation_forest': -1}
# Index: 37833, Data: {'LIQUIDITY_POOL_ADDRESS': '8Vs1ELHSkw6kt82u6seXQs3fASWbmoiTwFemgKoF9Z7q', 'MINT': '9TMAe89RXQTZ41QPWvxyfnrfyChuvDvC1eCaHhsZz7gz', 'TOTAL_ADDED_LIQUIDITY': 96000006512.3129, 'TOTAL_REMOVED_LIQUIDITY': 923.965808, 'NUM_LIQUIDITY_ADDS': 4.0, 'NUM_LIQUIDITY_REMOVES': 2.0, 'ADD_TO_REMOVE_RATIO': 103899955.692206, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1720108125, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1719960290, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 15.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 4.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 7.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 22.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 7.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06591681001175209, 'is_outlier_isolation_forest': -1}
# Index: 95188, Data: {'LIQUIDITY_POOL_ADDRESS': '99PpNKW9ca26nLPg5GHmJUZizxcjyDZHGefu6eMBW7fa', 'MINT': '7ZCm8WBN9aLa3o47SoYctU6iLdj7wkGG5SV2hE5CgtD5', 'TOTAL_ADDED_LIQUIDITY': 7394296715135.6, 'TOTAL_REMOVED_LIQUIDITY': 10548839792313.8, 'NUM_LIQUIDITY_ADDS': 41743.0, 'NUM_LIQUIDITY_REMOVES': 7268.0, 'ADD_TO_REMOVE_RATIO': 0.7009582912, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1730410635, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704067863, 'LAST_SWAP_TIMESTAMP_ts': 1730416125, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 21.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 31.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 23.0, 'LAST_SWAP_TIMESTAMP_day': 31.0, 'LAST_SWAP_TIMESTAMP_weekday': 3.0, 'LAST_SWAP_TIMESTAMP_month': 10.0, 'INACTIVITY_STATUS_Active': True, 'INACTIVITY_STATUS_Inactive': False, 'anomaly_score_isolation_forest': -0.06581335670098343, 'is_outlier_isolation_forest': -1}
# Index: 94104, Data: {'LIQUIDITY_POOL_ADDRESS': 'Goe5a1pRUxEZSjFLfGyXNUdb3rzeiQGWNBKPneR34TsG', 'MINT': 'H5ti8rLBe5aPxfLA7JokQHmHdobydXqkdWFdZ6U7M1S8', 'TOTAL_ADDED_LIQUIDITY': 37944532651477.5, 'TOTAL_REMOVED_LIQUIDITY': 46089012129736.8, 'NUM_LIQUIDITY_ADDS': 46.0, 'NUM_LIQUIDITY_REMOVES': 608.0, 'ADD_TO_REMOVE_RATIO': 0.8232880441, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1719163712, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704102287, 'LAST_SWAP_TIMESTAMP_ts': 1717019693, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 17.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 23.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 9.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 21.0, 'LAST_SWAP_TIMESTAMP_day': 29.0, 'LAST_SWAP_TIMESTAMP_weekday': 2.0, 'LAST_SWAP_TIMESTAMP_month': 5.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06537492947993706, 'is_outlier_isolation_forest': -1}
# Index: 86373, Data: {'LIQUIDITY_POOL_ADDRESS': '2qS6boYsGJbTSa7ruBR11BqvASNjHmR94ESmfADSTgDz', 'MINT': 'mZxEpyQiK6CXEfshR7F4gZ4U8yLpQdBuA3x7nJPvw6b', 'TOTAL_ADDED_LIQUIDITY': 345315486136837.0, 'TOTAL_REMOVED_LIQUIDITY': 735382501520734.0, 'NUM_LIQUIDITY_ADDS': 232.0, 'NUM_LIQUIDITY_REMOVES': 122.0, 'ADD_TO_REMOVE_RATIO': 0.4695726175, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1722540514, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1705941692, 'LAST_SWAP_TIMESTAMP_ts': 1723981385, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 19.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 8.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 16.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 22.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 11.0, 'LAST_SWAP_TIMESTAMP_day': 18.0, 'LAST_SWAP_TIMESTAMP_weekday': 6.0, 'LAST_SWAP_TIMESTAMP_month': 8.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06392714437186531, 'is_outlier_isolation_forest': -1}
# Index: 92258, Data: {'LIQUIDITY_POOL_ADDRESS': 'GHPZruHEBdv6qy6quXrsnjYrcCCT4otobVDmpGWg6HcB', 'MINT': 'C5EdtUghm2nibRXE49Rzf9mQRhLzQ93KJWjgnUwFJtb8', 'TOTAL_ADDED_LIQUIDITY': 9171358435532920.0, 'TOTAL_REMOVED_LIQUIDITY': 9494954561060230.0, 'NUM_LIQUIDITY_ADDS': 4.0, 'NUM_LIQUIDITY_REMOVES': 4.0, 'ADD_TO_REMOVE_RATIO': 0.9659191496, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1704311557, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704310951, 'LAST_SWAP_TIMESTAMP_ts': 1724626266, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 19.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 2.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 19.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 3.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 22.0, 'LAST_SWAP_TIMESTAMP_day': 25.0, 'LAST_SWAP_TIMESTAMP_weekday': 6.0, 'LAST_SWAP_TIMESTAMP_month': 8.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06364075911613554, 'is_outlier_isolation_forest': -1}
# Index: 85766, Data: {'LIQUIDITY_POOL_ADDRESS': 'HqByMkTg3hx55FSCYuBrwcudjwCJibTHeZvR3HbMRo9E', 'MINT': '6Ck7rXcdvC2BRQqLHmYJAEW3LkhRgdwe6ikkwrGhVMde', 'TOTAL_ADDED_LIQUIDITY': 12225272364428.3, 'TOTAL_REMOVED_LIQUIDITY': 12130735264940.0, 'NUM_LIQUIDITY_ADDS': 7.0, 'NUM_LIQUIDITY_REMOVES': 3.0, 'ADD_TO_REMOVE_RATIO': 1.007793188, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1729803794, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1706134889, 'LAST_SWAP_TIMESTAMP_ts': 1706186212, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 21.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 24.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 22.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 24.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 12.0, 'LAST_SWAP_TIMESTAMP_day': 25.0, 'LAST_SWAP_TIMESTAMP_weekday': 3.0, 'LAST_SWAP_TIMESTAMP_month': 1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06282810010079487, 'is_outlier_isolation_forest': -1}

# %%
subset_to_label.to_csv('/kaggle/working/subset_to_label.csv', index=False)
