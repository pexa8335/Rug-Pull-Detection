# %%
path = '/kaggle/input/ithack/Jan_2024-Nov_2024.csv'

# %%
import pandas as pd
df = pd.read_csv(path)

# %%
pip install scikit-learn==1.5.1
# Out:
# Requirement already satisfied: scikit-learn==1.5.1 in /usr/local/lib/python3.11/dist-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.1) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.1) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.1) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.1) (3.6.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.1) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.1) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.1) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.1) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.1) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.1) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.19.5->scikit-learn==1.5.1) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.19.5->scikit-learn==1.5.1) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.19.5->scikit-learn==1.5.1) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.19.5->scikit-learn==1.5.1) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.19.5->scikit-learn==1.5.1) (2024.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.5.1
# Summary: A set of python modules for machine learning and data mining
# Home-page: https://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: bayesian-optimization, Boruta, category_encoders, cesium, eli5, fastai, hdbscan, hep_ml, imbalanced-learn, librosa, lime, mlxtend, nilearn, pyLDAvis, pynndescent, rgf-python, scikit-learn-intelex, scikit-optimize, scikit-plot, sentence-transformers, shap, sklearn-compat, sklearn-pandas, TPOT, tsfresh, umap-learn, woodwork, yellowbrick
# Note: you may need to restart the kernel to use updated packages.

# %%
df
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                              LIQUIDITY_POOL_ADDRESS  \
# 0      HLx5KbazmBafQfmjiYHWQaYqrXbDbJCAYLQci74sFVtR
# 1      4pJqcD8QmhLajJYn9muEtXJSz67H8FaKtzNknFubardo
# 2      5e6BdkPuafUJuWGiUm5zayGRTYNDy7WkDZzNfiFpuQts
# 3      65j8XPXjd5ZhoHPtWDY4kKZKbgjJQhALPisrWrgWDhBg
# 4      65j8XPXjd5ZhoHPtWDY4kKZKbgjJQhALPisrWrgWDhBg
# ...                                             ...
# 95428  GpqMSH1YM6oPmJ5xxEE2KfePf7uf5rXFbTW2TnxicRj6
# 95429  GpqMSH1YM6oPmJ5xxEE2KfePf7uf5rXFbTW2TnxicRj6
# 95430  AVs9TA4nWDzfPJE9gGVNJMVhcQy3V9PGazuz33BfG2RA
# 95431  AVs9TA4nWDzfPJE9gGVNJMVhcQy3V9PGazuz33BfG2RA
# 95432                                             ﻿
#
#                                                MINT  TOTAL_ADDED_LIQUIDITY  \
# 0      8KDsEUE3NdafcCVPqKrMrPfqh3oT4FzcxsYjwbMqpump           3.727000e+05
# 1      47uYAPNpAMJrLLxQZ7QQ9F1T6XBHqfPHLTfLsCCapump           3.584071e+06
# 2       uBR78nzmdk1W6wRxETznhW9jEuunn7ZTc9W3MGqpump           1.944022e+06
# 3      5p2zjqCd1WJzAVgcEnjhb9zWDU7b9XVhFhx4usiyN7jB           2.617475e+04
# 4      BxXmDhM8sTF3QG4foaVM2v1EUvg9DLSVUsDRTjR8tMyS           2.011766e+06
# ...                                             ...                    ...
# 95428  7dHbWXmci3dT8UFYWYZweBLXgycu7Y3iL6trKn1Y7ARj           4.163527e+01
# 95429   USDH1SM1ojwWUga67PGrgFWUHibbjqMvuMaDkRJTgkX           5.010918e+03
# 95430  4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R           2.231211e+06
# 95431   So11111111111111111111111111111111111111112           2.644296e+04
# 95432                                           NaN                    NaN
#
#        TOTAL_REMOVED_LIQUIDITY  NUM_LIQUIDITY_ADDS  NUM_LIQUIDITY_REMOVES  \
# 0                 6.930945e+04                 2.0                    1.0
# 1                 1.895394e+06                 1.0                    1.0
# 2                 2.960122e+06                17.0                   12.0
# 3                 3.546890e+04                 3.0                    1.0
# 4                 5.417064e+03                 3.0                    1.0
# ...                        ...                 ...                    ...
# 95428             1.059945e+02            392380.0                  188.0
# 95429             1.060718e+04            392380.0                  188.0
# 95430             6.508533e+06             15009.0                10346.0
# 95431             7.588321e+04             15009.0                10346.0
# 95432                      NaN                 NaN                    NaN
#
#        ADD_TO_REMOVE_RATIO LAST_POOL_ACTIVITY_TIMESTAMP  \
# 0                 5.377333      2024-10-31 23:52:02.000
# 1                 1.890937      2024-10-31 23:32:37.000
# 2                 0.656737      2024-10-31 23:52:37.000
# 3                 0.737963      2024-10-31 23:16:28.000
# 4               371.375729      2024-10-31 23:16:28.000
# ...                    ...                          ...
# 95428             0.392806      2024-08-05 19:34:18.000
# 95429             0.472408      2024-08-05 19:34:18.000
# 95430             0.342813      2024-10-31 18:33:28.000
# 95431             0.348469      2024-10-31 18:33:28.000
# 95432                  NaN                          NaN
#
#       FIRST_POOL_ACTIVITY_TIMESTAMP      LAST_SWAP_TIMESTAMP  \
# 0           2024-10-31 23:41:11.000  2024-10-31 23:59:38.000
# 1           2024-10-31 23:32:14.000  2024-10-31 23:59:52.000
# 2           2024-10-31 23:32:04.000  2024-10-31 23:59:56.000
# 3           2024-10-31 23:09:45.000  2024-10-31 23:57:39.000
# 4           2024-10-31 23:09:45.000  2024-10-31 23:56:38.000
# ...                             ...                      ...
# 95428       2024-01-01 00:00:07.000  2024-10-31 23:57:21.000
# 95429       2024-01-01 00:00:07.000  2024-10-31 23:50:20.000
# 95430       2024-01-01 00:00:02.000  2024-10-31 23:59:13.000
# 95431       2024-01-01 00:00:02.000  2024-11-01 00:00:00.000
# 95432                           NaN                      NaN
#
#                                          LAST_SWAP_TX_ID INACTIVITY_STATUS
# 0      3Uc1L6z3iR6x11WjSKR6QwQvDT87JV9tFXfYa7WPX8tek6...            Active
# 1      5keT61KU7SeBLgz4FJTY9QESTHyDvHGVJDmha1wKsMk5U5...            Active
# 2      34B7xqS6mcFyd71icighCHRTg2BW2NLPUUBxnfh71fbiWC...            Active
# 3      eADFKxhPWAaGNkA5St5i695315fCYkunBv1QeEJUL1kAfu...            Active
# 4      4L5DBSsSqjThXDodGiFGZd6RQUg9yQG79MSzbCSrcGkXMd...            Active
# ...                                                  ...               ...
# 95428  5LC8g3BCFvWEYFEmvmhoF3uvEyzJnKMpi76kLBYNXwoTot...            Active
# 95429  dfSuFu4VzyB499egHxcgN7RXALwgnLvYERnozdEedjsKoJ...            Active
# 95430  3SxFS8BVTXTQ62sX4g3PXZbVrUvj7zc9CvPbvDCCN7ZuSG...            Active
# 95431  58dWq6mucodktckyMxtjtyHaiPW7PdiKVgSCELMD3oQG4x...            Active
# 95432                                                NaN               NaN
#
# [95433 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['LIQUIDITY_POOL_ADDRESS', 'MINT', 'TOTAL_ADDED_LIQUIDITY',
#        'TOTAL_REMOVED_LIQUIDITY', 'NUM_LIQUIDITY_ADDS',
#        'NUM_LIQUIDITY_REMOVES', 'ADD_TO_REMOVE_RATIO',
#        'LAST_POOL_ACTIVITY_TIMESTAMP', 'FIRST_POOL_ACTIVITY_TIMESTAMP',
#        'LAST_SWAP_TIMESTAMP', 'LAST_SWAP_TX_ID', 'INACTIVITY_STATUS'],
#       dtype='object')

# %%
df.isna().sum() / len(df) * 100
# Out:
# LIQUIDITY_POOL_ADDRESS           0.000000
# MINT                             0.001048
# TOTAL_ADDED_LIQUIDITY            0.001048
# TOTAL_REMOVED_LIQUIDITY          0.001048
# NUM_LIQUIDITY_ADDS               0.001048
# NUM_LIQUIDITY_REMOVES            0.001048
# ADD_TO_REMOVE_RATIO              0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP     0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP    0.001048
# LAST_SWAP_TIMESTAMP              0.540693
# LAST_SWAP_TX_ID                  0.540693
# INACTIVITY_STATUS                0.001048
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.shape
# Out:
# (95433, 12)

# %%
df.head().to_dict()
# Out:
# {'LIQUIDITY_POOL_ADDRESS': {0: 'HLx5KbazmBafQfmjiYHWQaYqrXbDbJCAYLQci74sFVtR',
#   1: '4pJqcD8QmhLajJYn9muEtXJSz67H8FaKtzNknFubardo',
#   2: '5e6BdkPuafUJuWGiUm5zayGRTYNDy7WkDZzNfiFpuQts',
#   3: '65j8XPXjd5ZhoHPtWDY4kKZKbgjJQhALPisrWrgWDhBg',
#   4: '65j8XPXjd5ZhoHPtWDY4kKZKbgjJQhALPisrWrgWDhBg'},
#  'MINT': {0: '8KDsEUE3NdafcCVPqKrMrPfqh3oT4FzcxsYjwbMqpump',
#   1: '47uYAPNpAMJrLLxQZ7QQ9F1T6XBHqfPHLTfLsCCapump',
#   2: 'uBR78nzmdk1W6wRxETznhW9jEuunn7ZTc9W3MGqpump',
#   3: '5p2zjqCd1WJzAVgcEnjhb9zWDU7b9XVhFhx4usiyN7jB',
#   4: 'BxXmDhM8sTF3QG4foaVM2v1EUvg9DLSVUsDRTjR8tMyS'},
#  'TOTAL_ADDED_LIQUIDITY': {0: 372699.999937,
#   1: 3584071.0,
#   2: 1944021.819549,
#   3: 26174.75462778,
#   4: 2011766.101511},
#  'TOTAL_REMOVED_LIQUIDITY': {0: 69309.446048,
#   1: 1895394.482757,
#   2: 2960122.351972,
#   3: 35468.90254633,
#   4: 5417.064025},
#  'NUM_LIQUIDITY_ADDS': {0: 2.0, 1: 1.0, 2: 17.0, 3: 3.0, 4: 3.0},
#  'NUM_LIQUIDITY_REMOVES': {0: 1.0, 1: 1.0, 2: 12.0, 3: 1.0, 4: 1.0},
#  'ADD_TO_REMOVE_RATIO': {0: 5.377333411,
#   1: 1.890936706,
#   2: 0.6567369819,
#   3: 0.7379634764,
#   4: 371.375729035},
#  'LAST_POOL_ACTIVITY_TIMESTAMP': {0: '2024-10-31 23:52:02.000',
#   1: '2024-10-31 23:32:37.000',
#   2: '2024-10-31 23:52:37.000',
#   3: '2024-10-31 23:16:28.000',
#   4: '2024-10-31 23:16:28.000'},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP': {0: '2024-10-31 23:41:11.000',
#   1: '2024-10-31 23:32:14.000',
#   2: '2024-10-31 23:32:04.000',
#   3: '2024-10-31 23:09:45.000',
#   4: '2024-10-31 23:09:45.000'},
#  'LAST_SWAP_TIMESTAMP': {0: '2024-10-31 23:59:38.000',
#   1: '2024-10-31 23:59:52.000',
#   2: '2024-10-31 23:59:56.000',
#   3: '2024-10-31 23:57:39.000',
#   4: '2024-10-31 23:56:38.000'},
#  'LAST_SWAP_TX_ID': {0: '3Uc1L6z3iR6x11WjSKR6QwQvDT87JV9tFXfYa7WPX8tek6oRoAaKS4fXZiFr8m4aS2ovrgmcAU2nc8fsBCYFsUo6',
#   1: '5keT61KU7SeBLgz4FJTY9QESTHyDvHGVJDmha1wKsMk5U5nzTsLfHZqCAFA47Q797RhXUanqdjWxyufi3pxtCkE1',
#   2: '34B7xqS6mcFyd71icighCHRTg2BW2NLPUUBxnfh71fbiWCWbMfRyrQ633QuVSk3BDYyZx3NPPzRmWyNneAvc5oNS',
#   3: 'eADFKxhPWAaGNkA5St5i695315fCYkunBv1QeEJUL1kAfuG2GF7EfVK8We6xm1PNCtRHexHoqfwEbqbkmjznkWK',
#   4: '4L5DBSsSqjThXDodGiFGZd6RQUg9yQG79MSzbCSrcGkXMdB6aR1yJLcqGPPf3b6qJpDKzbDLZZY1NsRMxYxSztbQ'},
#  'INACTIVITY_STATUS': {0: 'Active',
#   1: 'Active',
#   2: 'Active',
#   3: 'Active',
#   4: 'Active'}}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95433 entries, 0 to 95432
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   LIQUIDITY_POOL_ADDRESS         95433 non-null  object
#  1   MINT                           95432 non-null  object
#  2   TOTAL_ADDED_LIQUIDITY          95432 non-null  float64
#  3   TOTAL_REMOVED_LIQUIDITY        95432 non-null  float64
#  4   NUM_LIQUIDITY_ADDS             95432 non-null  float64
#  5   NUM_LIQUIDITY_REMOVES          95432 non-null  float64
#  6   ADD_TO_REMOVE_RATIO            95432 non-null  float64
#  7   LAST_POOL_ACTIVITY_TIMESTAMP   95432 non-null  object
#  8   FIRST_POOL_ACTIVITY_TIMESTAMP  95432 non-null  object
#  9   LAST_SWAP_TIMESTAMP            94917 non-null  object
#  10  LAST_SWAP_TX_ID                94917 non-null  object
#  11  INACTIVITY_STATUS              95432 non-null  object
# dtypes: float64(5), object(7)
# memory usage: 8.7+ MB

# %%
timestamp_cols = [
    'LAST_POOL_ACTIVITY_TIMESTAMP',
    'FIRST_POOL_ACTIVITY_TIMESTAMP',
    'LAST_SWAP_TIMESTAMP'
]

for col in timestamp_cols:
    df[col] = df[col].str.split('.').str[0]
    df[col] = pd.to_datetime(df[col], format='%Y-%m-%d %H:%M:%S', errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95433 entries, 0 to 95432
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   LIQUIDITY_POOL_ADDRESS         95433 non-null  object
#  1   MINT                           95432 non-null  object
#  2   TOTAL_ADDED_LIQUIDITY          95432 non-null  float64
#  3   TOTAL_REMOVED_LIQUIDITY        95432 non-null  float64
#  4   NUM_LIQUIDITY_ADDS             95432 non-null  float64
#  5   NUM_LIQUIDITY_REMOVES          95432 non-null  float64
#  6   ADD_TO_REMOVE_RATIO            95432 non-null  float64
#  7   LAST_POOL_ACTIVITY_TIMESTAMP   95432 non-null  datetime64[ns]
#  8   FIRST_POOL_ACTIVITY_TIMESTAMP  95432 non-null  datetime64[ns]
#  9   LAST_SWAP_TIMESTAMP            94917 non-null  datetime64[ns]
#  10  LAST_SWAP_TX_ID                94917 non-null  object
#  11  INACTIVITY_STATUS              95432 non-null  object
# dtypes: datetime64[ns](3), float64(5), object(4)
# memory usage: 8.7+ MB

# %%
datetime_cols = df.select_dtypes(include=['datetime64[ns]']).columns.tolist()

for col in datetime_cols:
    df[f"{col}_ts"] = df[col].astype('int64') // 10**9  # Giây

# %%
for col in datetime_cols:
    df[f'{col}_hour'] = df[col].dt.hour
    df[f'{col}_day'] = df[col].dt.day
    df[f'{col}_weekday'] = df[col].dt.weekday  # Monday = 0, Sunday = 6
    df[f'{col}_month'] = df[col].dt.month

# %%
df.isna().sum() / len(df) * 100
# Out:
# LIQUIDITY_POOL_ADDRESS                   0.000000
# MINT                                     0.001048
# TOTAL_ADDED_LIQUIDITY                    0.001048
# TOTAL_REMOVED_LIQUIDITY                  0.001048
# NUM_LIQUIDITY_ADDS                       0.001048
# NUM_LIQUIDITY_REMOVES                    0.001048
# ADD_TO_REMOVE_RATIO                      0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP             0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP            0.001048
# LAST_SWAP_TIMESTAMP                      0.540693
# LAST_SWAP_TX_ID                          0.540693
# INACTIVITY_STATUS                        0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_ts          0.000000
# FIRST_POOL_ACTIVITY_TIMESTAMP_ts         0.000000
# LAST_SWAP_TIMESTAMP_ts                   0.000000
# LAST_POOL_ACTIVITY_TIMESTAMP_hour        0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_day         0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_weekday     0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_month       0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_hour       0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_day        0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_weekday    0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_month      0.001048
# LAST_SWAP_TIMESTAMP_hour                 0.540693
# LAST_SWAP_TIMESTAMP_day                  0.540693
# LAST_SWAP_TIMESTAMP_weekday              0.540693
# LAST_SWAP_TIMESTAMP_month                0.540693
# dtype: float64

# %%
df.shape
# Out:
# (95433, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95433 entries, 0 to 95432
# Data columns (total 27 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   LIQUIDITY_POOL_ADDRESS                 95433 non-null  object
#  1   MINT                                   95432 non-null  object
#  2   TOTAL_ADDED_LIQUIDITY                  95432 non-null  float64
#  3   TOTAL_REMOVED_LIQUIDITY                95432 non-null  float64
#  4   NUM_LIQUIDITY_ADDS                     95432 non-null  float64
#  5   NUM_LIQUIDITY_REMOVES                  95432 non-null  float64
#  6   ADD_TO_REMOVE_RATIO                    95432 non-null  float64
#  7   LAST_POOL_ACTIVITY_TIMESTAMP           95432 non-null  datetime64[ns]
#  8   FIRST_POOL_ACTIVITY_TIMESTAMP          95432 non-null  datetime64[ns]
#  9   LAST_SWAP_TIMESTAMP                    94917 non-null  datetime64[ns]
#  10  LAST_SWAP_TX_ID                        94917 non-null  object
#  11  INACTIVITY_STATUS                      95432 non-null  object
#  12  LAST_POOL_ACTIVITY_TIMESTAMP_ts        95433 non-null  int64
#  13  FIRST_POOL_ACTIVITY_TIMESTAMP_ts       95433 non-null  int64
#  14  LAST_SWAP_TIMESTAMP_ts                 95433 non-null  int64
#  15  LAST_POOL_ACTIVITY_TIMESTAMP_hour      95432 non-null  float64
#  16  LAST_POOL_ACTIVITY_TIMESTAMP_day       95432 non-null  float64
#  17  LAST_POOL_ACTIVITY_TIMESTAMP_weekday   95432 non-null  float64
#  18  LAST_POOL_ACTIVITY_TIMESTAMP_month     95432 non-null  float64
#  19  FIRST_POOL_ACTIVITY_TIMESTAMP_hour     95432 non-null  float64
#  20  FIRST_POOL_ACTIVITY_TIMESTAMP_day      95432 non-null  float64
#  21  FIRST_POOL_ACTIVITY_TIMESTAMP_weekday  95432 non-null  float64
#  22  FIRST_POOL_ACTIVITY_TIMESTAMP_month    95432 non-null  float64
#  23  LAST_SWAP_TIMESTAMP_hour               94917 non-null  float64
#  24  LAST_SWAP_TIMESTAMP_day                94917 non-null  float64
#  25  LAST_SWAP_TIMESTAMP_weekday            94917 non-null  float64
#  26  LAST_SWAP_TIMESTAMP_month              94917 non-null  float64
# dtypes: datetime64[ns](3), float64(17), int64(3), object(4)
# memory usage: 19.7+ MB

# %%
df.drop(columns=datetime_cols, inplace=True)

# %%
numeric_cols = df.select_dtypes(include=['float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

# %%
numeric_cols
# Out:
# ['TOTAL_ADDED_LIQUIDITY',
#  'TOTAL_REMOVED_LIQUIDITY',
#  'NUM_LIQUIDITY_ADDS',
#  'NUM_LIQUIDITY_REMOVES',
#  'ADD_TO_REMOVE_RATIO',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_day',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_month',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_day',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_month',
#  'LAST_SWAP_TIMESTAMP_hour',
#  'LAST_SWAP_TIMESTAMP_day',
#  'LAST_SWAP_TIMESTAMP_weekday',
#  'LAST_SWAP_TIMESTAMP_month']

# %%
categorical_cols
# Out:
# ['LIQUIDITY_POOL_ADDRESS', 'MINT', 'LAST_SWAP_TX_ID', 'INACTIVITY_STATUS']

# %%
for col in df.columns:
    print(f"{col}: {df[col].dtype}")
# Out:
# LIQUIDITY_POOL_ADDRESS: object
# MINT: object
# TOTAL_ADDED_LIQUIDITY: float64
# TOTAL_REMOVED_LIQUIDITY: float64
# NUM_LIQUIDITY_ADDS: float64
# NUM_LIQUIDITY_REMOVES: float64
# ADD_TO_REMOVE_RATIO: float64
# LAST_SWAP_TX_ID: object
# INACTIVITY_STATUS: object
# LAST_POOL_ACTIVITY_TIMESTAMP_ts: int64
# FIRST_POOL_ACTIVITY_TIMESTAMP_ts: int64
# LAST_SWAP_TIMESTAMP_ts: int64
# LAST_POOL_ACTIVITY_TIMESTAMP_hour: float64
# LAST_POOL_ACTIVITY_TIMESTAMP_day: float64
# LAST_POOL_ACTIVITY_TIMESTAMP_weekday: float64
# LAST_POOL_ACTIVITY_TIMESTAMP_month: float64
# FIRST_POOL_ACTIVITY_TIMESTAMP_hour: float64
# FIRST_POOL_ACTIVITY_TIMESTAMP_day: float64
# FIRST_POOL_ACTIVITY_TIMESTAMP_weekday: float64
# FIRST_POOL_ACTIVITY_TIMESTAMP_month: float64
# LAST_SWAP_TIMESTAMP_hour: float64
# LAST_SWAP_TIMESTAMP_day: float64
# LAST_SWAP_TIMESTAMP_weekday: float64
# LAST_SWAP_TIMESTAMP_month: float64

# %%
datetime_cols = df.select_dtypes(include=['datetime64[ns]']).columns.tolist()

for col in datetime_cols:
    df[f"{col}_ts"] = df[col].astype('int64') // 10**9  # Giây

# %%
for col in datetime_cols:
    df[f'{col}_hour'] = df[col].dt.hour
    df[f'{col}_day'] = df[col].dt.day
    df[f'{col}_weekday'] = df[col].dt.weekday  # Monday = 0, Sunday = 6
    df[f'{col}_month'] = df[col].dt.month

# %%
df.shape
# Out:
# (95433, 24)

# %%
df.drop(columns=datetime_cols, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95433 entries, 0 to 95432
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   LIQUIDITY_POOL_ADDRESS                 95433 non-null  object
#  1   MINT                                   95432 non-null  object
#  2   TOTAL_ADDED_LIQUIDITY                  95432 non-null  float64
#  3   TOTAL_REMOVED_LIQUIDITY                95432 non-null  float64
#  4   NUM_LIQUIDITY_ADDS                     95432 non-null  float64
#  5   NUM_LIQUIDITY_REMOVES                  95432 non-null  float64
#  6   ADD_TO_REMOVE_RATIO                    95432 non-null  float64
#  7   LAST_SWAP_TX_ID                        94917 non-null  object
#  8   INACTIVITY_STATUS                      95432 non-null  object
#  9   LAST_POOL_ACTIVITY_TIMESTAMP_ts        95433 non-null  int64
#  10  FIRST_POOL_ACTIVITY_TIMESTAMP_ts       95433 non-null  int64
#  11  LAST_SWAP_TIMESTAMP_ts                 95433 non-null  int64
#  12  LAST_POOL_ACTIVITY_TIMESTAMP_hour      95432 non-null  float64
#  13  LAST_POOL_ACTIVITY_TIMESTAMP_day       95432 non-null  float64
#  14  LAST_POOL_ACTIVITY_TIMESTAMP_weekday   95432 non-null  float64
#  15  LAST_POOL_ACTIVITY_TIMESTAMP_month     95432 non-null  float64
#  16  FIRST_POOL_ACTIVITY_TIMESTAMP_hour     95432 non-null  float64
#  17  FIRST_POOL_ACTIVITY_TIMESTAMP_day      95432 non-null  float64
#  18  FIRST_POOL_ACTIVITY_TIMESTAMP_weekday  95432 non-null  float64
#  19  FIRST_POOL_ACTIVITY_TIMESTAMP_month    95432 non-null  float64
#  20  LAST_SWAP_TIMESTAMP_hour               94917 non-null  float64
#  21  LAST_SWAP_TIMESTAMP_day                94917 non-null  float64
#  22  LAST_SWAP_TIMESTAMP_weekday            94917 non-null  float64
#  23  LAST_SWAP_TIMESTAMP_month              94917 non-null  float64
# dtypes: float64(17), int64(3), object(4)
# memory usage: 17.5+ MB

# %%
numeric_cols = df.select_dtypes(include=['number']).columns.tolist()
numeric_cols
# Out:
# ['TOTAL_ADDED_LIQUIDITY',
#  'TOTAL_REMOVED_LIQUIDITY',
#  'NUM_LIQUIDITY_ADDS',
#  'NUM_LIQUIDITY_REMOVES',
#  'ADD_TO_REMOVE_RATIO',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_ts',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_ts',
#  'LAST_SWAP_TIMESTAMP_ts',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_day',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_month',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_day',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_month',
#  'LAST_SWAP_TIMESTAMP_hour',
#  'LAST_SWAP_TIMESTAMP_day',
#  'LAST_SWAP_TIMESTAMP_weekday',
#  'LAST_SWAP_TIMESTAMP_month']

# %%
time_cols = ['LAST_SWAP_TIMESTAMP_hour', 'LAST_SWAP_TIMESTAMP_day', 
             'LAST_SWAP_TIMESTAMP_weekday', 'LAST_SWAP_TIMESTAMP_month']

df[time_cols] = df[time_cols].fillna(-1)

# %%
df.isna().sum() / len(df) * 100
# Out:
# LIQUIDITY_POOL_ADDRESS                   0.000000
# MINT                                     0.001048
# TOTAL_ADDED_LIQUIDITY                    0.001048
# TOTAL_REMOVED_LIQUIDITY                  0.001048
# NUM_LIQUIDITY_ADDS                       0.001048
# NUM_LIQUIDITY_REMOVES                    0.001048
# ADD_TO_REMOVE_RATIO                      0.001048
# LAST_SWAP_TX_ID                          0.540693
# INACTIVITY_STATUS                        0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_ts          0.000000
# FIRST_POOL_ACTIVITY_TIMESTAMP_ts         0.000000
# LAST_SWAP_TIMESTAMP_ts                   0.000000
# LAST_POOL_ACTIVITY_TIMESTAMP_hour        0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_day         0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_weekday     0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_month       0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_hour       0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_day        0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_weekday    0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_month      0.001048
# LAST_SWAP_TIMESTAMP_hour                 0.000000
# LAST_SWAP_TIMESTAMP_day                  0.000000
# LAST_SWAP_TIMESTAMP_weekday              0.000000
# LAST_SWAP_TIMESTAMP_month                0.000000
# dtype: float64

# %%
df = df.drop(columns=['LAST_SWAP_TX_ID'])

# %%
numeric_with_nan = [
    col for col in df.select_dtypes(include=['number']).columns 
    if df[col].isnull().any()
]
numeric_with_nan
# Out:
# ['TOTAL_ADDED_LIQUIDITY',
#  'TOTAL_REMOVED_LIQUIDITY',
#  'NUM_LIQUIDITY_ADDS',
#  'NUM_LIQUIDITY_REMOVES',
#  'ADD_TO_REMOVE_RATIO',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_day',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_month',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_day',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_month']

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plot_mode = 'kde'

for col in numeric_with_nan:
    plt.figure(figsize=(6, 2))

    if plot_mode == 'hist':
        sns.histplot(data=df, x=col, kde=False, bins=30, color='skyblue', alpha=0.7)
    elif plot_mode == 'kde':
        sns.kdeplot(data=df, x=col, fill=True, color='skyblue', linewidth=2, bw_adjust=0.5)


    if 'is_anomaly' in df.columns:
        anomalies = df[df['is_anomaly'] == 1][col]
        plt.scatter(anomalies, [-0.005] * len(anomalies), color='red', label='Anomaly', marker='x', s=40)

    plt.title(f'{plot_mode.upper()} Plot with Anomalies: {col}')
    plt.xlabel(col)
    plt.legend(loc='upper right')
    plt.tight_layout()
    plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
col_to_fill_0 = ['TOTAL_ADDED_LIQUIDITY',                    
'TOTAL_REMOVED_LIQUIDITY',                  
'NUM_LIQUIDITY_ADDS',                       
'NUM_LIQUIDITY_REMOVES',                    
'ADD_TO_REMOVE_RATIO']
df[col_to_fill_0] = df[col_to_fill_0].fillna(0)

# %%
df.dropna(subset=['MINT'], inplace=True)

# %%
# Danh sách 8 cột đặc trưng thời gian suy ra
time_derived_features_to_fill = [
    'LAST_POOL_ACTIVITY_TIMESTAMP_hour',
    'LAST_POOL_ACTIVITY_TIMESTAMP_day',
    'LAST_POOL_ACTIVITY_TIMESTAMP_weekday',
    'LAST_POOL_ACTIVITY_TIMESTAMP_month',
    'FIRST_POOL_ACTIVITY_TIMESTAMP_hour',
    'FIRST_POOL_ACTIVITY_TIMESTAMP_day',
    'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday',
    'FIRST_POOL_ACTIVITY_TIMESTAMP_month'
]

# Sửa warning bằng cách gán lại trực tiếp
for col in time_derived_features_to_fill:
    if col in df.columns:
        df[col] = df[col].fillna(-1)

print("\nSố lượng NaN ở các cột thời gian suy ra sau khi điền:")
print(df[time_derived_features_to_fill].isnull().sum())
# Out:
# Số lượng NaN ở các cột thời gian suy ra sau khi điền:
# LAST_POOL_ACTIVITY_TIMESTAMP_hour        0
# LAST_POOL_ACTIVITY_TIMESTAMP_day         0
# LAST_POOL_ACTIVITY_TIMESTAMP_weekday     0
# LAST_POOL_ACTIVITY_TIMESTAMP_month       0
# FIRST_POOL_ACTIVITY_TIMESTAMP_hour       0
# FIRST_POOL_ACTIVITY_TIMESTAMP_day        0
# FIRST_POOL_ACTIVITY_TIMESTAMP_weekday    0
# FIRST_POOL_ACTIVITY_TIMESTAMP_month      0
# dtype: int64

# %%
df.isna().sum()/len(df)*100
# Out:
# LIQUIDITY_POOL_ADDRESS                   0.0
# MINT                                     0.0
# TOTAL_ADDED_LIQUIDITY                    0.0
# TOTAL_REMOVED_LIQUIDITY                  0.0
# NUM_LIQUIDITY_ADDS                       0.0
# NUM_LIQUIDITY_REMOVES                    0.0
# ADD_TO_REMOVE_RATIO                      0.0
# INACTIVITY_STATUS                        0.0
# LAST_POOL_ACTIVITY_TIMESTAMP_ts          0.0
# FIRST_POOL_ACTIVITY_TIMESTAMP_ts         0.0
# LAST_SWAP_TIMESTAMP_ts                   0.0
# LAST_POOL_ACTIVITY_TIMESTAMP_hour        0.0
# LAST_POOL_ACTIVITY_TIMESTAMP_day         0.0
# LAST_POOL_ACTIVITY_TIMESTAMP_weekday     0.0
# LAST_POOL_ACTIVITY_TIMESTAMP_month       0.0
# FIRST_POOL_ACTIVITY_TIMESTAMP_hour       0.0
# FIRST_POOL_ACTIVITY_TIMESTAMP_day        0.0
# FIRST_POOL_ACTIVITY_TIMESTAMP_weekday    0.0
# FIRST_POOL_ACTIVITY_TIMESTAMP_month      0.0
# LAST_SWAP_TIMESTAMP_hour                 0.0
# LAST_SWAP_TIMESTAMP_day                  0.0
# LAST_SWAP_TIMESTAMP_weekday              0.0
# LAST_SWAP_TIMESTAMP_month                0.0
# dtype: float64

# %%
inactivity_status_one_hot = pd.get_dummies(df['INACTIVITY_STATUS'], prefix='INACTIVITY_STATUS')


df = pd.concat([df, inactivity_status_one_hot], axis=1)

df.drop('INACTIVITY_STATUS', axis=1, inplace=True)

# %%
estimated_contamination = 0.005

# %%
import optuna
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import train_test_split 

def objective(trial, X_data):

    # Gợi ý các tham số cho Isolation Forest
    n_estimators = trial.suggest_int('n_estimators', 50, 300) # Số cây trong rừng
    max_samples = trial.suggest_int('max_samples', 100, min(2048, len(X_data))) # Số mẫu lấy để xây cây
    
    model = IsolationForest(n_estimators=n_estimators,
                            max_samples=max_samples,
                            contamination=estimated_contamination, # Sử dụng giá trị ước tính
                            random_state=trial.number) # Sử dụng trial.number để đa dạng hóa seed

    # Fit mô hình với toàn bộ tập dữ liệu đặc trưng
    model.fit(X_data)

    # Tính điểm bất thường
    anomaly_scores = model.decision_function(X_data)

    # Phân loại điểm thành "inliers" (điểm > 0) và "outliers" (điểm <= 0) dựa trên ngưỡng 0
    # (trước khi áp dụng ngưỡng contamination)
    inlier_scores = anomaly_scores[anomaly_scores > 0]
    outlier_scores = anomaly_scores[anomaly_scores <= 0]

    # Tính điểm trung vị cho từng nhóm
    # Xử lý trường hợp một trong hai nhóm rỗng
    median_inlier = np.median(inlier_scores) if len(inlier_scores) > 0 else 0
    median_outlier = np.median(outlier_scores) if len(outlier_scores) > 0 else 0

    # Hàm mục tiêu: Tối đa hóa sự khác biệt giữa trung vị inlier và trung vị outlier
    # Điểm bất thường càng âm càng tốt, nên median_outlier sẽ là một số âm.
    # median_inlier - median_outlier = median_inlier + abs(median_outlier) -> muốn giá trị này lớn
    objective_value = median_inlier - median_outlier

    # Optuna mặc định tìm cách minimize. Để tối đa hóa, ta trả về giá trị âm
    return -objective_value

# %%
columns_to_drop_for_X = [
    'LIQUIDITY_POOL_ADDRESS',
    'MINT', 
    'LAST_SWAP_TX_ID', 
    'LAST_POOL_ACTIVITY_TIMESTAMP_ts',
    'FIRST_POOL_ACTIVITY_TIMESTAMP_ts',
    'LAST_SWAP_TIMESTAMP_ts'
]
X = df.drop(columns=columns_to_drop_for_X, errors='ignore')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)
X_scaled_df.head()
# Out:
#    TOTAL_ADDED_LIQUIDITY  TOTAL_REMOVED_LIQUIDITY  NUM_LIQUIDITY_ADDS  \
# 0              -0.008871                -0.012606           -0.029401
# 1              -0.008871                -0.012606           -0.029477
# 2              -0.008871                -0.012606           -0.028265
# 3              -0.008871                -0.012606           -0.029326
# 4              -0.008871                -0.012606           -0.029326
#
#    NUM_LIQUIDITY_REMOVES  ADD_TO_REMOVE_RATIO  \
# 0              -0.024714            -0.008216
# 1              -0.024714            -0.008216
# 2              -0.023854            -0.008216
# 3              -0.024714            -0.008216
# 4              -0.024714            -0.008178
#
#    LAST_POOL_ACTIVITY_TIMESTAMP_hour  LAST_POOL_ACTIVITY_TIMESTAMP_day  \
# 0                           1.515921                          1.482466
# 1                           1.515921                          1.482466
# 2                           1.515921                          1.482466
# 3                           1.515921                          1.482466
# 4                           1.515921                          1.482466
#
#    LAST_POOL_ACTIVITY_TIMESTAMP_weekday  LAST_POOL_ACTIVITY_TIMESTAMP_month  \
# 0                              0.043632                            1.191685
# 1                              0.043632                            1.191685
# 2                              0.043632                            1.191685
# 3                              0.043632                            1.191685
# 4                              0.043632                            1.191685
#
#    FIRST_POOL_ACTIVITY_TIMESTAMP_hour  FIRST_POOL_ACTIVITY_TIMESTAMP_day  \
# 0                            1.557532                           1.714879
# 1                            1.557532                           1.714879
# 2                            1.557532                           1.714879
# 3                            1.557532                           1.714879
# 4                            1.557532                           1.714879
#
#    FIRST_POOL_ACTIVITY_TIMESTAMP_weekday  FIRST_POOL_ACTIVITY_TIMESTAMP_month  \
# 0                               0.064234                             1.576563
# 1                               0.064234                             1.576563
# 2                               0.064234                             1.576563
# 3                               0.064234                             1.576563
# 4                               0.064234                             1.576563
#
#    LAST_SWAP_TIMESTAMP_hour  LAST_SWAP_TIMESTAMP_day  \
# 0                  1.232931                 0.979497
# 1                  1.232931                 0.979497
# 2                  1.232931                 0.979497
# 3                  1.232931                 0.979497
# 4                  1.232931                 0.979497
#
#    LAST_SWAP_TIMESTAMP_weekday  LAST_SWAP_TIMESTAMP_month  \
# 0                     -0.20073                   0.014898
# 1                     -0.20073                   0.014898
# 2                     -0.20073                   0.014898
# 3                     -0.20073                   0.014898
# 4                     -0.20073                   0.014898
#
#    INACTIVITY_STATUS_Active  INACTIVITY_STATUS_Inactive
# 0                  0.499797                   -0.499797
# 1                  0.499797                   -0.499797
# 2                  0.499797                   -0.499797
# 3                  0.499797                   -0.499797
# 4                  0.499797                   -0.499797

# %%
study = optuna.create_study(direction='minimize')
study.optimize(lambda trial: objective(trial, X_scaled), n_trials=100) 
# In ra kết quả tốt nhất
print("\nKết quả tối ưu hóa:")
print(f"Tham số tốt nhất: {study.best_params}")
print(f"Giá trị hàm mục tiêu tốt nhất (âm của sự khác biệt trung vị): {study.best_value}")
# Out:
# [I 2025-05-22 13:37:54,812] A new study created in memory with name: no-name-b01975c7-7e93-45dd-845c-d5fc272b599c
# [I 2025-05-22 13:37:58,193] Trial 0 finished with value: -0.18592363793572503 and parameters: {'n_estimators': 215, 'max_samples': 512}. Best is trial 0 with value: -0.18592363793572503.
# [I 2025-05-22 13:38:02,118] Trial 1 finished with value: -0.1840165322530987 and parameters: {'n_estimators': 207, 'max_samples': 1659}. Best is trial 0 with value: -0.18592363793572503.
# [I 2025-05-22 13:38:05,616] Trial 2 finished with value: -0.19242112648095813 and parameters: {'n_estimators': 228, 'max_samples': 410}. Best is trial 2 with value: -0.19242112648095813.
# [I 2025-05-22 13:38:07,006] Trial 3 finished with value: -0.1948953960882239 and parameters: {'n_estimators': 89, 'max_samples': 462}. Best is trial 3 with value: -0.1948953960882239.
# [I 2025-05-22 13:38:10,075] Trial 4 finished with value: -0.19363447698564934 and parameters: {'n_estimators': 157, 'max_samples': 1239}. Best is trial 3 with value: -0.1948953960882239.
# [I 2025-05-22 13:38:14,862] Trial 5 finished with value: -0.19266942878905077 and parameters: {'n_estimators': 265, 'max_samples': 818}. Best is trial 3 with value: -0.1948953960882239.
# [I 2025-05-22 13:38:17,324] Trial 6 finished with value: -0.18848836141712141 and parameters: {'n_estimators': 190, 'max_samples': 164}. Best is trial 3 with value: -0.1948953960882239.
# [I 2025-05-22 13:38:20,959] Trial 7 finished with value: -0.19205209063689554 and parameters: {'n_estimators': 203, 'max_samples': 746}. Best is trial 3 with value: -0.1948953960882239.
# [I 2025-05-22 13:38:25,281] Trial 8 finished with value: -0.1837333809349301 and parameters: {'n_estimators': 229, 'max_samples': 1918}. Best is trial 3 with value: -0.1948953960882239.
# [I 2025-05-22 13:38:27,293] Trial 9 finished with value: -0.18186084216052603 and parameters: {'n_estimators': 106, 'max_samples': 1825}. Best is trial 3 with value: -0.1948953960882239.
# [I 2025-05-22 13:38:28,310] Trial 10 finished with value: -0.20596683988481593 and parameters: {'n_estimators': 52, 'max_samples': 1243}. Best is trial 10 with value: -0.20596683988481593.
# [I 2025-05-22 13:38:29,293] Trial 11 finished with value: -0.1901390456948625 and parameters: {'n_estimators': 50, 'max_samples': 1266}. Best is trial 10 with value: -0.20596683988481593.
# [I 2025-05-22 13:38
. Best is trial 37 with value: -0.21551984350003978.
# [I 2025-05-22 13:40:49,359] Trial 95 finished with value: -0.20900630156785016 and parameters: {'n_estimators': 54, 'max_samples': 314}. Best is trial 37 with value: -0.21551984350003978.
# [I 2025-05-22 13:40:50,219] Trial 96 finished with value: -0.22399948855979882 and parameters: {'n_estimators': 51, 'max_samples': 394}. Best is trial 96 with value: -0.22399948855979882.
# [I 2025-05-22 13:40:51,051] Trial 97 finished with value: -0.20501272416468178 and parameters: {'n_estimators': 53, 'max_samples': 414}. Best is trial 96 with value: -0.22399948855979882.
# [I 2025-05-22 13:40:51,818] Trial 98 finished with value: -0.19999917268662956 and parameters: {'n_estimators': 50, 'max_samples': 308}. Best is trial 96 with value: -0.22399948855979882.
# [I 2025-05-22 13:40:54,342] Trial 99 finished with value: -0.19498618596851655 and parameters: {'n_estimators': 195, 'max_samples': 157}. Best is trial 96 with value: -0.22399948855979882.
# Kết quả tối ưu hóa:
# Tham số tốt nhất: {'n_estimators': 51, 'max_samples': 394}
# Giá trị hàm mục tiêu tốt nhất (âm của sự khác biệt trung vị): -0.22399948855979882

# %%
best_params = study.best_params
best_model = IsolationForest(n_estimators=best_params['n_estimators'],
                             max_samples=best_params['max_samples'],
                             contamination=estimated_contamination, 
                             random_state=42) 

# Fit mô hình tốt nhất với toàn bộ dữ liệu để sử dụng
best_model.fit(X_scaled)
# Out:
# IsolationForest(contamination=0.005, max_samples=394, n_estimators=51,
#                 random_state=42)

# %%
# Bây giờ bạn có thể sử dụng best_model để tính điểm bất thường và dự đoán nhãn
anomaly_scores_tuned = best_model.decision_function(X_scaled)
predictions_tuned = best_model.predict(X_scaled)

# %%
df['anomaly_score_isolation_forest'] = anomaly_scores_tuned
df['is_outlier_isolation_forest'] = predictions_tuned

# %%
# Xem 10 hàng có điểm bất thường thấp nhất (bất thường nhất)
top_anomalies = df.sort_values(by='anomaly_score_isolation_forest').head(10)
print("\nTop 10 ứng viên Rug Pull dựa trên điểm bất thường:")
print(top_anomalies)

# Xem tất cả các hàng được dự đoán là outliers (-1)
predicted_outliers_df = df[df['is_outlier_isolation_forest'] == -1]
print(f"\nSố lượng điểm được dự đoán là outliers: {len(predicted_outliers_df)}")
print("Thông tin về các điểm được dự đoán là outliers:")
print(predicted_outliers_df.head())
# Out:
# Top 10 ứng viên Rug Pull dựa trên điểm bất thường:
#                              LIQUIDITY_POOL_ADDRESS  \
# 11961  5no8Tr7WBcXjTEwtLa6MVuzFvL6Liv1rnki3AFhFv1om
# 47606  Fptmpk3UW6KcVTFFpoWv53eiji8dn2jVaZDNhHEhxCYy
# 29575  7sJ6qfKZvSNqSSPJKTVZBww21SQuAr5CDy8TUzNPjG6b
# 47913  8bCQiauSvZjB2FSL83pVHMZrgfFbYY5ff7cdMUpz4FVq
# 95256  3ne4mWqdYuNiYrYZC9TrA3FcfuFdErghH97vNPbjicr1
# 84580  E5yLGHhe8PxughUVLRvFsc9ufcWviGRczW92moTGmzLJ
# 82756  95rearCVnMKa7hfBC8R6NLaN5Kw1xxBSruG1eX33VsA4
# 90510  2tNb7AXu7A8caCJRNJy9izVAnhywV7zyouvqJ3EcCGKd
# 55636  BAxJwA7FMcHjmZVwFp2a1sGqKu6b8npJZovD4rEM4TkK
# 59664   v6NDnpPfRRQA5aMh5Ec5VKcy3kTvqdWFuhBGij1ox6n
#
#                                                MINT  TOTAL_ADDED_LIQUIDITY  \
# 11961  8RweLrRJ7kQ1Kk6Uqd3fs8Hees295p3CYa7yiycGH8Lw           5.000000e+14
# 47606  4XgoqVmM4D3ts697pghaCZcK2JvsdA8JYCxc4aerZF2Y           6.859382e+10
# 29575  3UrGrYW8ampNzLbx8LP7HyKig27EapBA4TkFwoKiP5Kp           1.402633e+10
# 47913  5adgZL4TvU4GnaJ76g91up8AaLj7cqu3CvYyVXmSNPdb           6.602291e+10
# 95256  DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263           2.287393e+12
# 84580  F2wSK4m7jirMsBSJCrgct2iSU3BnGjGzbk7bs1X8QutG           1.000002e+12
# 82756  7vNuRmaESRCKNGaxb5kHhszDxTSdmyEhNR6n2nEehKyF           1.000000e+12
# 90510  DGw78vT4Ljo7K2DAZWYeR3PAUCuFzR7y8Hh48PMKV7sm           8.489137e+13
# 55636  8exuywH7jW6AXBAb9f878uddLpPHjJFtNTxjZCjW4L3J           3.446811e+13
# 59664  EpEpjviv3wsyQNAVPMyjXuet2ELtfPkv5yWuUvsEY5Fj           1.000000e+13
#
#        TOTAL_REMOVED_LIQUIDITY  NUM_LIQUIDITY_ADDS  NUM_LIQUIDITY_REMOVES  \
# 11961             5.000000e+14                 1.0                    1.0
# 47606             2.524209e+03                 6.0                    5.0
# 29575             1.611971e+02                 2.0                    1.0
# 47913             3.229444e+03                 2.0                    1.0
# 95256             2.847503e+12            186415.0                87226.0
# 84580             1.000002e+12                 2.0                    2.0
# 82756             1.000000e+12                 2.0                    4.0
# 90510             1.868618e+15                 1.0                    4.0
# 55636             3.211485e+08                 4.0                    4.0
# 59664             8.174919e+12                 1.0                   12.0
#
#        ADD_TO_REMOVE_RATIO  LAST_POOL_ACTIVITY_TIMESTAMP_ts  \
# 11961         1.000000e+00                       1727392728
# 47606         2.717439e+07                       1728870578
# 29575         8.701355e+07                       1728153341
# 47913         2.044405e+07                       1728871018
# 95256         8.032978e-01                       1730418928
# 84580         1.000000e+00                       1706447191
# 82756         1.000000e+00                       1706922659
# 90510         4.543003e-02                       1706646532
# 55636         1.073276e+05                       1718043620
# 59664         1.223254e+00                       1714560046
#
#        FIRST_POOL_ACTIVITY_TIMESTAMP_ts  LAST_SWAP_TIMESTAMP_ts  ...  \
# 11961                        1727391322             -9223372037  ...
# 47606                        1717552481             -9223372037  ...
# 29575                        1721746718             -9223372037  ...
# 47913                        1717480275             -9223372037  ...
# 95256                        1704067581              1730419136  ...
# 84580                        1706445104             -9223372037  ...
# 82756                        1706920217             -9223372037  ...
# 90510                        1704768016              1706455498  ...
# 55636                        1715647495             -9223372037  ...
# 59664                        1714392624              1714532559  ...
#
#        FIRST_POOL_ACTIVITY_TIMESTAMP_month  LAST_SWAP_TIMESTAMP_hour  \
# 11961                                  9.0                      -1.0
# 47606                                  6.0                      -1.0
# 29575                                  7.0                      -1.0
# 47913                                  6.0                      -1.0
# 95256                                  1.0                      23.0
# 84580                                  1.0                      -1.0
# 82756                                  2.0                      -1.0
# 90510                                  1.0                      15.0
# 55636                                  5.0                      -1.0
# 59664                                  4.0                       3.0
#
#        LAST_SWAP_TIMESTAMP_day  LAST_SWAP_TIMESTAMP_weekday  \
# 11961                     -1.0                         -1.0
# 47606                     -1.0                         -1.0
# 29575                     -1.0                         -1.0
# 47913                     -1.0                         -1.0
# 95256                     31.0                          3.0
# 84580                     -1.0                         -1.0
# 82756                     -1.0                         -1.0
# 90510                     28.0                          6.0
# 55636                     -1.0                         -1.0
# 59664                      1.0                          2.0
#
#        LAST_SWAP_TIMESTAMP_month  INACTIVITY_STATUS_Active  \
# 11961                       -1.0                     False
# 47606                       -1.0                     False
# 29575                       -1.0                     False
# 47913                       -1.0                     False
# 95256                       10.0                      True
# 84580                       -1.0                     False
# 82756                       -1.0                     False
# 90510                        1.0                     False
# 55636                       -1.0                     False
# 59664                        5.0                     False
#
#        INACTIVITY_STATUS_Inactive  anomaly_score_isolation_forest  \
# 11961                        True                       -0.089536
# 47606                        True                       -0.087655
# 29575                        True                       -0.078128
# 47913                        True                       -0.076833
# 95256                       False                       -0.075112
# 84580                        True                       -0.073540
# 82756                        True                       -0.073378
# 90510                        True                       -0.072904
# 55636                        True                       -0.070921
# 59664                        True                       -0.069325
#
#        is_outlier_isolation_forest  true_label
# 11961                           -1         NaN
# 47606                           -1         NaN
# 29575                           -1         NaN
# 47913                           -1         NaN
# 95256                           -1         NaN
# 84580                           -1         NaN
# 82756                           -1         NaN
# 90510                           -1         NaN
# 55636                           -1         NaN
# 59664                           -1         NaN
#
# [10 rows x 27 columns]
#
# Số lượng điểm được dự đoán là outliers: 478
# Thông tin về các điểm được dự đoán là outliers:
#                             LIQUIDITY_POOL_ADDRESS  \
# 4028  9p4LGr6oAHWie8A8QGtS1BZUyBRvCBezo9uj8Fpbg9g4
# 4618   TDqw2ERGMAZgAhpgH1RA9mRGuFyzJxn2fiYbPJZPRVH
# 7400  7CvWY12ikyG2RX2r3YtajY88bMwCG7dHLiiumpPYegsv
# 9435  39znRLRpPLm2ZUiTWNmAyCNZ2axqghxSsyAN3uqFR3V6
# 9761  Cufy53mPuewJyKrYdoDg8CiDwbEEKuqe5Uw6HFouEmaN
#
#                                               MINT  TOTAL_ADDED_LIQUIDITY  \
# 4028  CgFdo4U7Vd1PviMM2yvbhVpaZDVtaxwVA6m8Z3vdArJx           9.000000e+09
# 4618  3Vse7Heee7Yb3U95vjQXDHqDBor6ERNQrA88GjeSVVj3           1.000000e+10
# 7400  FCTD4vHdWesmAqapE8r95yKUkrdZ7PFZbzD9UPigbL6z           6.475591e+13
# 9435  EJ6jksYHCh6TNqgF9pkAYmk8P4WTgcRAvkLKLiC58Lsn           5.117197e+12
# 9761  F6YyycaAJ5m7obW4HQ8AYvPPsQWuAbf4c4LMwjjtEnp3           7.866406e+12
#
#       TOTAL_REMOVED_LIQUIDITY  NUM_LIQUIDITY_ADDS  NUM_LIQUIDITY_REMOVES  \
# 4028             9.000000e+09                 1.0                    2.0
# 4618             5.027987e+00                 2.0                    1.0
# 7400             6.475591e+13                 1.0                    1.0
# 9435             1.859036e+12                44.0                    5.0
# 9761             6.977903e+12                10.0                    3.0
#
#       ADD_TO_REMOVE_RATIO  LAST_POOL_ACTIVITY_TIMESTAMP_ts  \
# 4028         1.000000e+00                       1729473076
# 4618         1.988868e+09                       1729376656
# 7400         1.000000e+00                       1729293334
# 9435         2.752607e+00                       1728370971
# 9761         1.127331e+00                       1728140031
#
#       FIRST_POOL_ACTIVITY_TIMESTAMP_ts  LAST_SWAP_TIMESTAMP_ts  ...  \
# 4028                        1729449831             -9223372037  ...
# 4618                        1729328484              1729414796  ...
# 7400                        1728709902              1724438040  ...
# 9435                        1728139099              1729865771  ...
# 9761                        1728041988              1728279019  ...
#
#       FIRST_POOL_ACTIVITY_TIMESTAMP_month  LAST_SWAP_TIMESTAMP_hour  \
# 4028                                 10.0                      -1.0
# 4618                                 10.0                       8.0
# 7400                                 10.0                      18.0
# 9435                                 10.0                      14.0
# 9761                                 10.0                       5.0
#
#       LAST_SWAP_TIMESTAMP_day  LAST_SWAP_TIMESTAMP_weekday  \
# 4028                     -1.0                         -1.0
# 4618                     20.0                          6.0
# 7400                     23.0                          4.0
# 9435                     25.0                          4.0
# 9761                      7.0                          0.0
#
#       LAST_SWAP_TIMESTAMP_month  INACTIVITY_STATUS_Active  \
# 4028                       -1.0                     False
# 4618                       10.0                     False
# 7400                        8.0                     False
# 9435                       10.0                     False
# 9761                       10.0                     False
#
#       INACTIVITY_STATUS_Inactive  anomaly_score_isolation_forest  \
# 4028                        True                       -0.015719
# 4618                        True                       -0.010804
# 7400                        True                       -0.003813
# 9435                        True                       -0.003398
# 9761                        True                       -0.022744
#
#       is_outlier_isolation_forest  true_label
# 4028                           -1         NaN
# 4618                           -1         NaN
# 7400                           -1         NaN
# 9435                           -1         NaN
# 9761                           -1         NaN
#
# [5 rows x 27 columns]
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()

# %%
anomaly_candidates_df = df[df['is_outlier_isolation_forest'] == -1]
anomaly_candidates_df.head(1).to_dict()
# Out:
# {'LIQUIDITY_POOL_ADDRESS': {4028: '9p4LGr6oAHWie8A8QGtS1BZUyBRvCBezo9uj8Fpbg9g4'},
#  'MINT': {4028: 'CgFdo4U7Vd1PviMM2yvbhVpaZDVtaxwVA6m8Z3vdArJx'},
#  'TOTAL_ADDED_LIQUIDITY': {4028: 9000000000.0},
#  'TOTAL_REMOVED_LIQUIDITY': {4028: 8999999992.5078},
#  'NUM_LIQUIDITY_ADDS': {4028: 1.0},
#  'NUM_LIQUIDITY_REMOVES': {4028: 2.0},
#  'ADD_TO_REMOVE_RATIO': {4028: 1.000000001},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_ts': {4028: 1729473076},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': {4028: 1729449831},
#  'LAST_SWAP_TIMESTAMP_ts': {4028: -9223372037},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_hour': {4028: 1.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_day': {4028: 21.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': {4028: 0.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_month': {4028: 10.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': {4028: 18.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_day': {4028: 20.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': {4028: 6.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_month': {4028: 10.0},
#  'LAST_SWAP_TIMESTAMP_hour': {4028: -1.0},
#  'LAST_SWAP_TIMESTAMP_day': {4028: -1.0},
#  'LAST_SWAP_TIMESTAMP_weekday': {4028: -1.0},
#  'LAST_SWAP_TIMESTAMP_month': {4028: -1.0},
#  'INACTIVITY_STATUS_Active': {4028: False},
#  'INACTIVITY_STATUS_Inactive': {4028: True},
#  'anomaly_score_isolation_forest': {4028: -0.015719428428036197},
#  'is_outlier_isolation_forest': {4028: -1},
#  'true_label': {4028: nan}}

# %%
subset_to_label = df.sort_values(by='anomaly_score_isolation_forest').head(478)
indices_to_label = subset_to_label.index

# %%
df['true_label'] = np.nan

# %%
import joblib
import os 
output_dir = '/kaggle/working/'

model_filename = 'isolation_forest_model.joblib'

#save model
output_path = os.path.join(output_dir, model_filename)
print(f"Saving model to: {output_path}")
joblib.dump(best_model, output_path)
print("Saving model successfully.")

# Save scaler
scaler_filename = "scaler.pkl"
scaler_output_path = os.path.join(output_dir, scaler_filename)
print(f"Saving scaler to: {scaler_output_path}")
joblib.dump(scaler, scaler_output_path)
print("Saving scaler successfully.")
# Out:
# Saving model to: /kaggle/working/isolation_forest_model.joblib
# Saving model successfully.
# Saving scaler to: /kaggle/working/scaler.pkl
# Saving scaler successfully.

# %%
subset_to_label.head(10).to_dict()
# Out:
# {'LIQUIDITY_POOL_ADDRESS': {11961: '5no8Tr7WBcXjTEwtLa6MVuzFvL6Liv1rnki3AFhFv1om',
#   47606: 'Fptmpk3UW6KcVTFFpoWv53eiji8dn2jVaZDNhHEhxCYy',
#   29575: '7sJ6qfKZvSNqSSPJKTVZBww21SQuAr5CDy8TUzNPjG6b',
#   47913: '8bCQiauSvZjB2FSL83pVHMZrgfFbYY5ff7cdMUpz4FVq',
#   95256: '3ne4mWqdYuNiYrYZC9TrA3FcfuFdErghH97vNPbjicr1',
#   84580: 'E5yLGHhe8PxughUVLRvFsc9ufcWviGRczW92moTGmzLJ',
#   82756: '95rearCVnMKa7hfBC8R6NLaN5Kw1xxBSruG1eX33VsA4',
#   90510: '2tNb7AXu7A8caCJRNJy9izVAnhywV7zyouvqJ3EcCGKd',
#   55636: 'BAxJwA7FMcHjmZVwFp2a1sGqKu6b8npJZovD4rEM4TkK',
#   59664: 'v6NDnpPfRRQA5aMh5Ec5VKcy3kTvqdWFuhBGij1ox6n'},
#  'MINT': {11961: '8RweLrRJ7kQ1Kk6Uqd3fs8Hees295p3CYa7yiycGH8Lw',
#   47606: '4XgoqVmM4D3ts697pghaCZcK2JvsdA8JYCxc4aerZF2Y',
#   29575: '3UrGrYW8ampNzLbx8LP7HyKig27EapBA4TkFwoKiP5Kp',
#   47913: '5adgZL4TvU4GnaJ76g91up8AaLj7cqu3CvYyVXmSNPdb',
#   95256: 'DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263',
#   84580: 'F2wSK4m7jirMsBSJCrgct2iSU3BnGjGzbk7bs1X8QutG',
#   82756: '7vNuRmaESRCKNGaxb5kHhszDxTSdmyEhNR6n2nEehKyF',
#   90510: 'DGw78vT4Ljo7K2DAZWYeR3PAUCuFzR7y8Hh48PMKV7sm',
#   55636: '8exuywH7jW6AXBAb9f878uddLpPHjJFtNTxjZCjW4L3J',
#   59664: 'EpEpjviv3wsyQNAVPMyjXuet2ELtfPkv5yWuUvsEY5Fj'},
#  'TOTAL_ADDED_LIQUIDITY': {11961: 499999999999997.0,
#   47606: 68593822519.1516,
#   29575: 14026333456.1265,
#   47913: 66022910039.2474,
#   95256: 2287393143117.23,
#   84580: 1000001655971.15,
#   82756: 999999999999.997,
#   90510: 84891372622828.6,
#   55636: 34468110069736.2,
#   59664: 10000000000000.0},
#  'TOTAL_REMOVED_LIQUIDITY': {11961: 499999999999997.0,
#   47606: 2524.208505,
#   29575: 161.197109,
#   47913: 3229.443534,
#   95256: 2847503355904.54,
#   84580: 1000001655971.15,
#   82756: 999999999999.997,
#   90510: 1868618094235160.0,
#   55636: 321148468.190506,
#   59664: 8174919357773.58},
#  'NUM_LIQUIDITY_ADDS': {11961: 1.0,
#   47606: 6.0,
#   29575: 2.0,
#   47913: 2.0,
#   95256: 186415.0,
#   84580: 2.0,
#   82756: 2.0,
#   90510: 1.0,
#   55636: 4.0,
#   59664: 1.0},
#  'NUM_LIQUIDITY_REMOVES': {11961: 1.0,
#   47606: 5.0,
#   29575: 1.0,
#   47913: 1.0,
#   95256: 87226.0,
#   84580: 2.0,
#   82756: 4.0,
#   90510: 4.0,
#   55636: 4.0,
#   59664: 12.0},
#  'ADD_TO_REMOVE_RATIO': {11961: 1.0,
#   47606: 27174388.4799055,
#   29575: 87013554.6669546,
#   47913: 20444051.5352412,
#   95256: 0.8032977866,
#   84580: 1.0,
#   82756: 1.0,
#   90510: 0.04543002815,
#   55636: 107327.648996568,
#   59664: 1.223253657},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_ts': {11961: 1727392728,
#   47606: 1728870578,
#   29575: 1728153341,
#   47913: 1728871018,
#   95256: 1730418928,
#   84580: 1706447191,
#   82756: 1706922659,
#   90510: 1706646532,
#   55636: 1718043620,
#   59664: 1714560046},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': {11961: 1727391322,
#   47606: 1717552481,
#   29575: 1721746718,
#   47913: 1717480275,
#   95256: 1704067581,
#   84580: 1706445104,
#   82756: 1706920217,
#   90510: 1704768016,
#   55636: 1715647495,
#   59664: 1714392624},
#  'LAST_SWAP_TIMESTAMP_ts': {11961: -9223372037,
#   47606: -9223372037,
#   29575: -9223372037,
#   47913: -9223372037,
#   95256: 1730419136,
#   84580: -9223372037,
#   82756: -9223372037,
#   90510: 1706455498,
#   55636: -9223372037,
#   59664: 1714532559},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_hour': {11961: 23.0,
#   47606: 1.0,
#   29575: 18.0,
#   47913: 1.0,
#   95256: 23.0,
#   84580: 13.0,
#   82756: 1.0,
#   90510: 20.0,
#   55636: 18.0,
#   59664: 10.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_day': {11961: 26.0,
#   47606: 14.0,
#   29575: 5.0,
#   47913: 14.0,
#   95256: 31.0,
#   84580: 28.0,
#   82756: 3.0,
#   90510: 30.0,
#   55636: 10.0,
#   59664: 1.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': {11961: 3.0,
#   47606: 0.0,
#   29575: 5.0,
#   47913: 0.0,
#   95256: 3.0,
#   84580: 6.0,
#   82756: 5.0,
#   90510: 1.0,
#   55636: 0.0,
#   59664: 2.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_month': {11961: 9.0,
#   47606: 10.0,
#   29575: 10.0,
#   47913: 10.0,
#   95256: 10.0,
#   84580: 1.0,
#   82756: 2.0,
#   90510: 1.0,
#   55636: 6.0,
#   59664: 5.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': {11961: 22.0,
#   47606: 1.0,
#   29575: 14.0,
#   47913: 5.0,
#   95256: 0.0,
#   84580: 12.0,
#   82756: 0.0,
#   90510: 2.0,
#   55636: 0.0,
#   59664: 12.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_day': {11961: 26.0,
#   47606: 5.0,
#   29575: 23.0,
#   47913: 4.0,
#   95256: 1.0,
#   84580: 28.0,
#   82756: 3.0,
#   90510: 9.0,
#   55636: 14.0,
#   59664: 29.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': {11961: 3.0,
#   47606: 2.0,
#   29575: 1.0,
#   47913: 1.0,
#   95256: 0.0,
#   84580: 6.0,
#   82756: 5.0,
#   90510: 1.0,
#   55636: 1.0,
#   59664: 0.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_month': {11961: 9.0,
#   47606: 6.0,
#   29575: 7.0,
#   47913: 6.0,
#   95256: 1.0,
#   84580: 1.0,
#   82756: 2.0,
#   90510: 1.0,
#   55636: 5.0,
#   59664: 4.0},
#  'LAST_SWAP_TIMESTAMP_hour': {11961: -1.0,
#   47606: -1.0,
#   29575: -1.0,
#   47913: -1.0,
#   95256: 23.0,
#   84580: -1.0,
#   82756: -1.0,
#   90510: 15.0,
#   55636: -1.0,
#   59664: 3.0},
#  'LAST_SWAP_TIMESTAMP_day': {11961: -1.0,
#   47606: -1.0,
#   29575: -1.0,
#   47913: -1.0,
#   95256: 31.0,
#   84580: -1.0,
#   82756: -1.0,
#   90510: 28.0,
#   55636: -1.0,
#   59664: 1.0},
#  'LAST_SWAP_TIMESTAMP_weekday': {11961: -1.0,
#   47606: -1.0,
#   29575: -1.0,
#   47913: -1.0,
#   95256: 3.0,
#   84580: -1.0,
#   82756: -1.0,
#   90510: 6.0,
#   55636: -1.0,
#   59664: 2.0},
#  'LAST_SWAP_TIMESTAMP_month': {11961: -1.0,
#   47606: -1.0,
#   29575: -1.0,
#   47913: -1.0,
#   95256: 10.0,
#   84580: -1.0,
#   82756: -1.0,
#   90510: 1.0,
#   55636: -1.0,
#   59664: 5.0},
#  'INACTIVITY_STATUS_Active': {11961: False,
#   47606: False,
#   29575: False,
#   47913: False,
#   95256: True,
#   84580: False,
#   82756: False,
#   90510: False,
#   55636: False,
#   59664: False},
#  'INACTIVITY_STATUS_Inactive': {11961: True,
#   47606: True,
#   29575: True,
#   47913: True,
#   95256: False,
#   84580: True,
#   82756: True,
#   90510: True,
#   55636: True,
#   59664: True},
#  'anomaly_score_isolation_forest': {11961: -0.08953615406646609,
#   47606: -0.08765461622242265,
#   29575: -0.07812773896531122,
#   47913: -0.076832620733709,
#   95256: -0.07511191598498401,
#   84580: -0.0735397140985341,
#   82756: -0.07337837699557737,
#   90510: -0.07290405571491088,
#   55636: -0.07092137628607809,
#   59664: -0.06932542286548449},
#  'is_outlier_isolation_forest': {11961: -1,
#   47606: -1,
#   29575: -1,
#   47913: -1,
#   95256: -1,
#   84580: -1,
#   82756: -1,
#   90510: -1,
#   55636: -1,
#   59664: -1},
#  'true_label': {11961: nan,
#   47606: nan,
#   29575: nan,
#   47913: nan,
#   95256: nan,
#   84580: nan,
#   82756: nan,
#   90510: nan,
#   55636: nan,
#   59664: nan}}

# %%
for i, row in subset_to_label.head(30).iterrows():
    print(f"Index: {i}, Data: {row.to_dict()}")
# Out:
# Index: 11961, Data: {'LIQUIDITY_POOL_ADDRESS': '5no8Tr7WBcXjTEwtLa6MVuzFvL6Liv1rnki3AFhFv1om', 'MINT': '8RweLrRJ7kQ1Kk6Uqd3fs8Hees295p3CYa7yiycGH8Lw', 'TOTAL_ADDED_LIQUIDITY': 499999999999997.0, 'TOTAL_REMOVED_LIQUIDITY': 499999999999997.0, 'NUM_LIQUIDITY_ADDS': 1.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1727392728, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1727391322, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 23.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 9.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 22.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 9.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.08953615406646609, 'is_outlier_isolation_forest': -1, 'true_label': nan}
# Index: 47606, Data: {'LIQUIDITY_POOL_ADDRESS': 'Fptmpk3UW6KcVTFFpoWv53eiji8dn2jVaZDNhHEhxCYy', 'MINT': '4XgoqVmM4D3ts697pghaCZcK2JvsdA8JYCxc4aerZF2Y', 'TOTAL_ADDED_LIQUIDITY': 68593822519.1516, 'TOTAL_REMOVED_LIQUIDITY': 2524.208505, 'NUM_LIQUIDITY_ADDS': 6.0, 'NUM_LIQUIDITY_REMOVES': 5.0, 'ADD_TO_REMOVE_RATIO': 27174388.4799055, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1728870578, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1717552481, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 6.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.08765461622242265, 'is_outlier_isolation_forest': -1, 'true_label': nan}
# Index: 29575, Data: {'LIQUIDITY_POOL_ADDRESS': '7sJ6qfKZvSNqSSPJKTVZBww21SQuAr5CDy8TUzNPjG6b', 'MINT': '3UrGrYW8ampNzLbx8LP7HyKig27EapBA4TkFwoKiP5Kp', 'TOTAL_ADDED_LIQUIDITY': 14026333456.1265, 'TOTAL_REMOVED_LIQUIDITY': 161.197109, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 87013554.6669546, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1728153341, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1721746718, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 18.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 5.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 5.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 14.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 23.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 7.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.07812773896531122, 'is_outlier_isolation_forest': -1, 'true_label': nan}
# Index: 47913, Data: {'LIQUIDITY_POOL_ADDRESS': '8bCQiauSvZjB2FSL83pVHMZrgfFbYY5ff7cdMUpz4FVq', 'MINT': '5adgZL4TvU4GnaJ76g91up8AaLj7cqu3CvYyVXmSNPdb', 'TOTAL_ADDED_LIQUIDITY': 66022910039.2474, 'TOTAL_REMOVED_LIQUIDITY': 3229.443534, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 20444051.5352412, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1728871018, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1717480275, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 4.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 6.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.076832620733709, 'is_outlier_isolation_forest': -1, 'true_label': nan}
# Index: 95256, Data: {'LIQUIDITY_POOL_ADDRESS': '3ne4mWqdYuNiYrYZC9TrA3FcfuFdErghH97vNPbjicr1', 'MINT': 'DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263', 'TOTAL_ADDED_LIQUIDITY': 2287393143117.23, 'TOTAL_REMOVED_LIQUIDITY': 2847503355904.54, 'NUM_LIQUIDITY_ADDS': 186415.0, 'NUM_LIQUIDITY_REMOVES': 87226.0, 'ADD_TO_REMOVE_RATIO': 0.8032977866, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1730418928, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704067581, 'LAST_SWAP_TIMESTAMP_ts': 1730419136, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 23.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 31.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 23.0, 'LAST_SWAP_TIMESTAMP_day': 31.0, 'LAST_SWAP_TIMESTAMP_weekday': 3.0, 'LAST_SWAP_TIMESTAMP_month': 10.0, 'INACTIVITY_STATUS_Active': True, 'INACTIVITY_STATUS_Inactive': False, 'anomaly_score_isolation_forest': -0.07511191598498401, 'is_outlier_isolation_forest': -1, 'true_label': nan}
# Index: 84580, Data: {'LIQUIDITY_POOL_ADDRESS': 'E5yLGHhe8PxughUVLRvFsc9ufcWviGRczW92moTGmzLJ', 'MINT': 'F2wSK4m7jirMsBSJCrgct2iSU3BnGjGzbk7bs1X8QutG', 'TOTAL_ADDED_LIQUIDITY': 1000001655971.15, 'TOTAL_REMOVED_LIQUIDITY': 1000001655971.15, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 2.0, 'ADD_TO_REMOVE_RATIO': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1706447191, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1706445104, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 13.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 28.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 12.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 28.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.0735397140985341, 'is_outlier_isolation_forest': -1, 'true_label': nan}
# Index:
 'is_outlier_isolation_forest': -1, 'true_label': nan}
# Index: 91575, Data: {'LIQUIDITY_POOL_ADDRESS': '137Wy4xiPi6j7ssUaowH2DVg972Juf4btmg6p8LfgsnH', 'MINT': '23h3L2UxzdsmWntfAGJQNcFZ7iQb5sgzMR2JbaoduCmc', 'TOTAL_ADDED_LIQUIDITY': 70907372981422.9, 'TOTAL_REMOVED_LIQUIDITY': 67307125634181.2, 'NUM_LIQUIDITY_ADDS': 10.0, 'NUM_LIQUIDITY_REMOVES': 40.0, 'ADD_TO_REMOVE_RATIO': 1.053489839, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1705254323, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704467868, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 17.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 15.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 4.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06213399917907236, 'is_outlier_isolation_forest': -1, 'true_label': nan}
# Index: 50982, Data: {'LIQUIDITY_POOL_ADDRESS': '51GLh7Z2whymNkpBy4HnschqRMjR2KsvrJ1jwMcE1inj', 'MINT': 'H9YtnULnyHMPiAkD5tFwCpB3sDtmNUdi8cGuTkMYvtXm', 'TOTAL_ADDED_LIQUIDITY': 384439153922.226, 'TOTAL_REMOVED_LIQUIDITY': 39191.100013, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 9809348.39273979, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1728870164, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1716807031, 'LAST_SWAP_TIMESTAMP_ts': 1716826848, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 27.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 5.0, 'LAST_SWAP_TIMESTAMP_hour': 16.0, 'LAST_SWAP_TIMESTAMP_day': 27.0, 'LAST_SWAP_TIMESTAMP_weekday': 0.0, 'LAST_SWAP_TIMESTAMP_month': 5.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.0614361670710285, 'is_outlier_isolation_forest': -1, 'true_label': nan}
# Index: 85149, Data: {'LIQUIDITY_POOL_ADDRESS': '2NbYW9NUVufMHKnuCM1mpmeTysHEGAcHq3EDL85kqi8w', 'MINT': '5ovWbyonBsts6kWsS49v5H3aDL61u8ahGGCSiWJhdoLp', 'TOTAL_ADDED_LIQUIDITY': 3607843703705510.0, 'TOTAL_REMOVED_LIQUIDITY': 1257636386632490.0, 'NUM_LIQUIDITY_ADDS': 6.0, 'NUM_LIQUIDITY_REMOVES': 8.0, 'ADD_TO_REMOVE_RATIO': 2.868749459, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1706296585, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1706293891, 'LAST_SWAP_TIMESTAMP_ts': 1712101672, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 19.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 4.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 18.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 4.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 23.0, 'LAST_SWAP_TIMESTAMP_day': 2.0, 'LAST_SWAP_TIMESTAMP_weekday': 1.0, 'LAST_SWAP_TIMESTAMP_month': 4.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06140563626032214, 'is_outlier_isolation_forest': -1, 'true_label': nan}
# Index: 37833, Data: {'LIQUIDITY_POOL_ADDRESS': '8Vs1ELHSkw6kt82u6seXQs3fASWbmoiTwFemgKoF9Z7q', 'MINT': '9TMAe89RXQTZ41QPWvxyfnrfyChuvDvC1eCaHhsZz7gz', 'TOTAL_ADDED_LIQUIDITY': 96000006512.3129, 'TOTAL_REMOVED_LIQUIDITY': 923.965808, 'NUM_LIQUIDITY_ADDS': 4.0, 'NUM_LIQUIDITY_REMOVES': 2.0, 'ADD_TO_REMOVE_RATIO': 103899955.692206, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1720108125, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1719960290, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 15.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 4.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 7.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 22.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 7.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06133768494763381, 'is_outlier_isolation_forest': -1, 'true_label': nan}
# Index: 88888, Data: {'LIQUIDITY_POOL_ADDRESS': '7RUSgjFttQRonLBkvwRqENR3GMeqBm7aNkLQQwKAX5Zy', 'MINT': '8hS1TLmxWhT3C42i6Bnb8Bj2s1o5YN9W2c1JDmdH4JsC', 'TOTAL_ADDED_LIQUIDITY': 165916201929092.0, 'TOTAL_REMOVED_LIQUIDITY': 423122614640657.0, 'NUM_LIQUIDITY_ADDS': 230.0, 'NUM_LIQUIDITY_REMOVES': 104.0, 'ADD_TO_REMOVE_RATIO': 0.3921232196, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1718302344, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1705245215, 'LAST_SWAP_TIMESTAMP_ts': 1714599875, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 18.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 13.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 15.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 21.0, 'LAST_SWAP_TIMESTAMP_day': 1.0, 'LAST_SWAP_TIMESTAMP_weekday': 2.0, 'LAST_SWAP_TIMESTAMP_month': 5.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06128014998721931, 'is_outlier_isolation_forest': -1, 'true_label': nan}
# Index: 84726, Data: {'LIQUIDITY_POOL_ADDRESS': 'BmHuXoh9xG1FxK3GFqDAaamv5vnvXpEHzS1odccpMgGL', 'MINT': '52QaBoDMTKTZBoGT7jZgpjpHJq5v4r1mEPH641q8V1Zg', 'TOTAL_ADDED_LIQUIDITY': 129871219592.476, 'TOTAL_REMOVED_LIQUIDITY': 129871219592.476, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 2.0, 'ADD_TO_REMOVE_RATIO': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1706401947, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1706401087, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 28.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 28.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.060078171037142525, 'is_outlier_isolation_forest': -1, 'true_label': nan}
# Index: 50063, Data: {'LIQUIDITY_POOL_ADDRESS': '2PfJD5aKpzqBGPGduN8z9NGcZxcygAkkzneGS1vpJjCe', 'MINT': '7Emb92dbMEbsbRcePc8YqxSRcHCrWrgHgMLiDJ5XrECY', 'TOTAL_ADDED_LIQUIDITY': 25001278978.0665, 'TOTAL_REMOVED_LIQUIDITY': 3307.036648, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 7560024.77117591, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1727253786, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1716988571, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 8.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 25.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 2.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 9.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 13.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 29.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 5.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.05976069024406783, 'is_outlier_isolation_forest': -1, 'true_label': nan}
# Index: 85218, Data: {'LIQUIDITY_POOL_ADDRESS': '7BZzoP3QB2zK3R7WqRzjS5fpeeErgdy3HGzxXrN97aEY', 'MINT': 'WENWENvqqNya429ubCdR81ZmD69brwQaaBYY6p3LCpk', 'TOTAL_ADDED_LIQUIDITY': 281046926625.469, 'TOTAL_REMOVED_LIQUIDITY': 287391580680.628, 'NUM_LIQUIDITY_ADDS': 109590.0, 'NUM_LIQUIDITY_REMOVES': 133353.0, 'ADD_TO_REMOVE_RATIO': 0.9779233127, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1730419177, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1706284478, 'LAST_SWAP_TIMESTAMP_ts': 1730419177, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 23.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 31.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 15.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 4.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 23.0, 'LAST_SWAP_TIMESTAMP_day': 31.0, 'LAST_SWAP_TIMESTAMP_weekday': 3.0, 'LAST_SWAP_TIMESTAMP_month': 10.0, 'INACTIVITY_STATUS_Active': True, 'INACTIVITY_STATUS_Inactive': False, 'anomaly_score_isolation_forest': -0.05965651173530517, 'is_outlier_isolation_forest': -1, 'true_label': nan}

# %%
subset_to_label.to_csv('/kaggle/working/subset_to_label.csv', index=False)
